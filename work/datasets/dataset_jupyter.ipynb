# %%
import os
import csv
import json
from tqdm import tqdm

# %% [markdown]
# ## CEA

# %%
from pymongo import MongoClient

import os

MONGO_ENDPOINT = os.environ['MONGO_ENDPOINT']
MONGO_PORT = os.environ['MONGO_PORT']
MONGO_ENDPOINT_USERNAME = os.environ['MONGO_INITDB_ROOT_USERNAME']
MONGO_ENDPOINT_PASSWORD = os.environ['MONGO_INITDB_ROOT_PASSWORD']
MONGO_DBNAME = os.environ['MONGO_DBNAME']
mongo_client = MongoClient(
                            MONGO_ENDPOINT, 
                            int(MONGO_PORT), 
                            username=MONGO_ENDPOINT_USERNAME, 
                            password=MONGO_ENDPOINT_PASSWORD, 
                            authSource='admin'
                        )

def get_collection(collection_name):
    return mongo_client[MONGO_DBNAME][collection_name]

def index_field(collection_name, field_name):
    mongo_client[MONGO_DBNAME][collection_name].create_index([ (field_name, 1) ], unique=True)

def get_entity(collection_name, entity):
    return mongo_client[MONGO_DBNAME][collection_name].find_one({ 'entity': entity })

def insert_many_entity(collection_name, entities):
    mongo_client[MONGO_DBNAME][collection_name].insert_many(entities)

def get_cell_retrieval(collection_name, cell):
    return mongo_client[MONGO_DBNAME][collection_name].find_one({"cell": cell})

# %%
import requests

headers = {
    "accept": "application/json",
    "Content-Type": "application/json"
}
def lookup(cell):
    lookup_response = []
    params = {
        'token': "insideslab-lamapi-2022",
        'name': cell,
        'kg': "wikidata",
        'limit': 10
    }
    result = requests.get("https://lamapi.inside.disco.unimib.it/lookup/entity-retrieval-with-array", headers=headers, params=params).json()
    if len(result[cell.lower()]) > 0:
        for entity in result[cell.lower()]:
            lookup_response.append({'id': entity['id'], 'label': entity['name']})
    return lookup_response

def column_analysis(columns):
    params = {
        'token': "insideslab-lamapi-2022",
    }
    result = requests.post("https://lamapi.inside.disco.unimib.it/sti/column-analysis", headers=headers, params=params, json={"json": columns}).json()
    return result

# %%
def column_analysis(columns):
    params = {
        'token': "insideslab-lamapi-2022",
    }
    result = requests.post("https://lamapi.inside.disco.unimib.it/sti/column-analysis", headers=headers, params=params, json={"json": columns}).json()
    return result

def lookup(cells):
    lookup_response = []
    params = {
        'token': "insideslab-lamapi-2022",
        'kg': "wikidata",
        'limit': 10
    }
    result = requests.post("https://lamapi.inside.disco.unimib.it/lookup/entity-retrieval-with-array", headers=headers, params=params, json={"cells": cells}).json()
    for key, value in result.items():
        current_lookup_result = {"name": key, "entities": []}
        for entity in value:
            current_lookup_result["entities"].append({'id': entity['id'], 'label': entity['name']})
        lookup_response.append(current_lookup_result)
    return lookup_response

# %%
class GroundTruthItemCEA:
    def __init__(self, table, row, column, value):
        self.table: str = table
        self.row: str = row
        self.column: str = column
        self.value: str = value

    def get_item(self) -> dict[str, str]:
        return {
            'table': self.table,
            'row': self.row,
            'column': self.column,
        }
    
    @property
    def get_identifier(self) -> str:
        return f'{self.row}_{self.column}'
    
    @property
    def get_output(self) -> str:
        return f'({self.row},{self.column})={self.value}'

    def __str__(self) -> str:
        return f'{self.table} {self.row} {self.column} {self.value}'

class GroundTruthCEA:
    def __init__(self, filename):
        self.filename: str = filename
        self.ground_truth: dict[str, dict[str, GroundTruthItemCEA]] = {}

    @property
    def total(self) -> int:
        return len(self.ground_truth)
    
    def number_of_items_in_csv(self) -> int:
        with open(self.filename, 'r') as f:
            reader = csv.reader(f)
            total: int = 0
            for _ in reader:
                total += 1
            return total

    def load(self):
        with open(self.filename, 'r') as f:
            print('Loading ground truth...')
            total_lines: int = self.number_of_items_in_csv()
            print(f'Total lines: {total_lines}')
            reader = csv.reader(f)
            for row in tqdm(reader, total=total_lines):
                current_gt: GroundTruthItemCEA = GroundTruthItemCEA(row[0], row[1], row[2], row[3])
                if current_gt.table in self.ground_truth:
                    self.ground_truth[current_gt.table][current_gt.get_identifier] = current_gt
                else:
                    self.ground_truth[current_gt.table] = {
                        current_gt.get_identifier: current_gt
                    }

class Dataset():

    def __init__(self, gt_dataset: GroundTruthCEA, dataset_name: str, filename: str):
        self.filename: str = filename
        self.dataset_name: str = dataset_name
        self.gt_dataset = gt_dataset
        self.llm_dataset: list[dict[str, str]] = []
        self.instruction = "perform the cell entity annotation (cea) task on this table:"
        self.lookup_cache = {}

    def parse_table(self, table_representation: str) -> str:
        columns_list = {}
        rows = table_representation.split('|')
        for row in rows:
            columns = row.split(';')
            for index, cell in enumerate(columns):
                if index not in columns_list:
                    columns_list[index] = [cell]
                else:
                    columns_list[index].append(cell)
        all_columns = []
        for _, column in columns_list.items():
            all_columns.append(column)
        return all_columns
    
    def format_pool(self, pool: list[dict[str, str]]) -> str:
        pool_representation = ""
        for entity in pool:
            pool_representation += entity + "|"
        return pool_representation[:-1]

    def get_pool(self, table_representation: str) -> list[dict[str, str]]:
        pool = set()
        columns_list = self.parse_table(table_representation)
        for column in columns_list:
            for cell in column:
                cell_retrieval = get_cell_retrieval("candidate", cell.lower())
                if cell_retrieval is not None:
                    for entity in cell_retrieval['candidates']['entities'][0:3]:
                        pool.add(f"{entity['id']} [{entity['label']}]")

        return self.format_pool(pool)

    def get_output(self, table_name: str) -> str | None:
        outputCEA: str = ""
        if table_name not in self.gt_dataset.ground_truth:
            return None
        for _, gtTable in self.gt_dataset.ground_truth[table_name].items():
            if gtTable.value != "UNKNOWN":
                current_entity_label = get_entity("entities", gtTable.value.replace('http://www.wikidata.org/entity/', ''))
                if current_entity_label is not None and 'label' in current_entity_label:
                    outputCEA += gtTable.get_output.replace('http://www.wikidata.org/entity/', '') + f" [{current_entity_label['label']}]" + "|"
                else:
                    outputCEA += gtTable.get_output.replace('http://www.wikidata.org/entity/', '') + "|"
            else:
                return None

        return outputCEA

    def load_tables(self):
        all_csv_tables = os.listdir(self.filename)
        print("LOAD TABLES...")
        for csv_table in tqdm(all_csv_tables, total=len(all_csv_tables)):
            table_name: str = csv_table.split('.')[0]
            print(table_name)
            table_representation: str = ""
            with open(os.path.join(self.filename, csv_table), 'r') as f:
                reader = csv.reader(f)
                next(reader, None)
                for row in reader:
                    table_representation += ";".join(row) + "|"
                table_representation = table_representation[:-1]
                pool = self.get_pool(table_representation)
                current_output = self.get_output(table_name)
                if current_output is None:
                    continue
                self.llm_dataset.append({
                    'dataset': self.dataset_name,
                    'table': table_name,
                    'instruction': self.instruction,
                    'input': table_representation,
                    "output": current_output,
                    "pool": pool
                })

# %%
cea_datasets: list[dict[str, str]] = [
    {"gt": "./wikidata/SemTab2020_Table_GT_Target/GT/CEA/CEA_Round1_gt.csv", "tables": "./wikidata/SemTab2020_Table_GT_Target/Round1/tables", "dataset": "semtab_2020_r1"}, # SemTab2020_Table_GT_Target R1
    {"gt": "./wikidata/SemTab2020_Table_GT_Target/GT/CEA/CEA_Round2_gt.csv", "tables": "./wikidata/SemTab2020_Table_GT_Target/Round2/tables", "dataset": "semtab_2020_r2"}, # SemTab2020_Table_GT_Target R2
    {"gt": "./wikidata/SemTab2020_Table_GT_Target/GT/CEA/CEA_Round3_gt.csv", "tables": "./wikidata/SemTab2020_Table_GT_Target/Round3/tables", "dataset": "semtab_2020_r3"}, # SemTab2020_Table_GT_Target R3
    {"gt": "./wikidata/SemTab2020_Table_GT_Target/GT/CEA/CEA_Round4_gt.csv", "tables": "./wikidata/SemTab2020_Table_GT_Target/Round4/tables", "dataset": "semtab_2020_r4"}, # SemTab2020_Table_GT_Target R4
    {"gt": "./wikidata/HardTablesR1/DataSets/HardTablesR1/Valid/gt/cea_gt.csv", "tables": "./wikidata/HardTablesR1/DataSets/HardTablesR1/Valid/tables", "dataset": "hardtables_2022_r1"}, # HardTablesR1 2022
    {"gt": "./wikidata/HardTablesR2/DataSets/HardTablesR2/Valid/gt/cea_gt.csv", "tables": "./wikidata/HardTablesR2/DataSets/HardTablesR2/Valid/tables", "dataset": "hardtables_2022_r2"}, # HardTablesR2 2022
    {"gt": "./wikidata/WikidataTables2023R1/DataSets/Valid/gt/cea_gt.csv", "tables": "./wikidata/WikidataTables2023R1/DataSets/Valid/tables", "dataset": "wikidata_tables_2023"}, # Wikidata Tables 2023
]

# %%
import requests

headers = {
    "accept": "application/json",
    "Content-Type": "application/json"
}
def column_analysis(columns):
    params = {
        'token': "insideslab-lamapi-2022",
    }
    result = requests.post("https://lamapi.inside.disco.unimib.it/sti/column-analysis", headers=headers, params=params, json={"json": columns}).json()
    return result

def lookup(cell):
    current_lookup_result = {}
    params = {
        'token': "insideslab-lamapi-2022",
        'name': cell,
        'kg': "wikidata",
        'limit': 10
    }
    result = requests.get("https://lamapi.inside.disco.unimib.it/lookup/entity-retrieval", headers=headers, params=params).json()
    for key, value in result.items():
        current_lookup_result = {"name": key, "entities": []}
        for entity in value:
            current_lookup_result["entities"].append({'id': entity['id'], 'label': entity['name']})
    return current_lookup_result

cell_set = set()
cell_buffer = []
for dataset in cea_datasets:
    all_csv_tables = os.listdir(dataset['tables'])
    for csv_table in tqdm(all_csv_tables, total=len(all_csv_tables)):
            table_name: str = csv_table.split('.')[0]
            with open(os.path.join(dataset['tables'], csv_table), 'r') as f:
                reader = csv.reader(f)
                next(reader, None)
                columns = {}
                for row in reader:
                    for index, cell in enumerate(row):
                        if index not in columns:
                            columns[index] = [cell]
                        else:
                            columns[index].append(cell)
                columns_to_annotate = []
                for _, column in columns.items():
                    columns_to_annotate.append(column)
                annotated_columns = column_analysis(columns_to_annotate)
                for key, val in annotated_columns.items():
                    if val['tag'] == "NE":
                        for cell in val['column_rows']:
                            if cell.lower() not in cell_set:
                                cell_set.add(cell.lower())
                                result = lookup(cell.lower())
                                cell_buffer.append({"name": cell.lower(), "entities": result})
                if len(cell_buffer) > 10:
                    insert_many_entity("cell_retrieval", list(cell_buffer))
                    cell_buffer = []

if len(cell_buffer) > 0:
    insert_many_entity("cell_retrieval", list(cell_buffer))
    cell_buffer = []
# Out:
#   0%|          | 0/34294 [00:00<?, ?it/s]
#   0%|          | 95/34294 [02:08<12:53:23,  1.36s/it]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /home/jovyan/work/datasets/dataset_jupyter.ipynb Cella 8 line 5
#      <a href='vscode-notebook-cell://attached-container%2B7b22636f6e7461696e65724e616d65223a222f7374695f6c6c6d5f6a757079746572227d@ssh-remote%2B74.234.142.60/home/jovyan/work/datasets/dataset_jupyter.ipynb#X10sdnNjb2RlLXJlbW90ZQ%3D%3D?line=51'>52</a>             if cell.lower() not in cell_set:
#      <a href='vscode-notebook-cell://attached-container%2B7b22636f6e7461696e65724e616d65223a222f7374695f6c6c6d5f6a757079746572227d@ssh-remote%2B74.234.142.60/home/jovyan/work/datasets/dataset_jupyter.ipynb#X10sdnNjb2RlLXJlbW90ZQ%3D%3D?line=52'>53</a>                 cell_set.add(cell.lower())
# ---> <a href='vscode-notebook-cell://attached-container%2B7b22636f6e7461696e65724e616d65223a222f7374695f6c6c6d5f6a757079746572227d@ssh-remote%2B74.234.142.60/home/jovyan/work/datasets/dataset_jupyter.ipynb#X10sdnNjb2RlLXJlbW90ZQ%3D%3D?line=53'>54</a>                 result = lookup(cell.lower())
#      <a href='vscode-notebook-cell://attached-container%2B7b22636f6e7461696e65724e616d65223a222f7374695f6c6c6d5f6a757079746572227d@ssh-remote%2B74.234.142.60/home/jovyan/work/datasets/dataset_jupyter.ipynb#X10sdnNjb2RlLXJlbW90ZQ%3D%3D?line=54'>55</a>                 cell_buffer.append({"name": cell.lower(), "entities": result})
#      <a href='vscode-notebook-cell://attached-container%2B7b22636f6e7461696e65724e616d65223a222f7374695f6c6c6d5f6a757079746572227d@ssh-remote%2B74.234.142.60/home/jovyan/work/datasets/dataset_jupyter.ipynb#X10sdnNjb2RlLXJlbW90ZQ%3D%3D?line=55'>56</a> if len(cell_buffer) > 10:
#
# /home/jovyan/work/datasets/dataset_jupyter.ipynb Cella 8 line 2
#      <a href='vscode-notebook-cell://attached-container%2B7b22636f6e7461696e65724e616d65223a222f7374695f6c6c6d5f6a757079746572227d@ssh-remote%2B74.234.142.60/home/jovyan/work/datasets/dataset_jupyter.ipynb#X10sdnNjb2RlLXJlbW90ZQ%3D%3D?line=14'>15</a> current_lookup_result = {}
#      <a href='vscode-notebook-cell://attached-container%2B7b22636f6e7461696e65724e616d65223a222f7374695f6c6c6d5f6a757079746572227d@ssh-remote%2B74.234.142.60/home/jovyan/work/datasets/dataset_jupyter.ipynb#X10sdnNjb2RlLXJlbW90ZQ%3D%3D?line=15'>16</a> params = {
#      <a href='vscode-notebook-cell://attached-container%2B7b22636f6e7461696e65724e616d65223a222f7374695f6c6c6d5f6a757079746572227d@ssh-remote%2B74.234.142.60/home/jovyan/work/datasets/dataset_jupyter.ipynb#X10sdnNjb2RlLXJlbW90ZQ%3D%3D?line=16'>17</a>     'token': "insideslab-lamapi-2022",
#      <a href='vscode-notebook-cell://attached-container%2B7b22636f6e7461696e65724e616d65223a222f7374695f6c6c6d5f6a757079746572227d@ssh-remote%2B74.234.142.60/home/jovyan/work/datasets/dataset_jupyter.ipynb#X10sdnNjb2RlLXJlbW90ZQ%3D%3D?line=17'>18</a>     'name': cell,
#      <a href='vscode-notebook-cell://attached-container%2B7b22636f6e7461696e65724e616d65223a222f7374695f6c6c6d5f6a757079746572227d@ssh-remote%2B74.234.142.60/home/jovyan/work/datasets/dataset_jupyter.ipynb#X10sdnNjb2RlLXJlbW90ZQ%3D%3D?line=18'>19</a>     'kg': "wikidata",
#      <a href='vscode-notebook-cell://attached-container%2B7b22636f6e7461696e65724e616d65223a222f7374695f6c6c6d5f6a757079746572227d@ssh-remote%2B74.234.142.60/home/jovyan/work/datasets/dataset_jupyter.ipynb#X10sdnNjb2RlLXJlbW90ZQ%3D%3D?line=19'>20</a>     'limit': 10
#      <a href='vscode-notebook-cell://attached-container%2B7b22636f6e7461696e65724e616d65223a222f7374695f6c6c6d5f6a757079746572227d@ssh-remote%2B74.234.142.60/home/jovyan/work/datasets/dataset_jupyter.ipynb#X10sdnNjb2RlLXJlbW90ZQ%3D%3D?line=20'>21</a> }
# ---> <a href='vscode-notebook-cell://attached-container%2B7b22636f6e7461696e65724e616d65223a222f7374695f6c6c6d5f6a757079746572227d@ssh-remote%2B74.234.142.60/home/jovyan/work/datasets/dataset_jupyter.ipynb#X10sdnNjb2RlLXJlbW90ZQ%3D%3D?line=21'>22</a> result = requests.get("https://lamapi.inside.disco.unimib.it/lookup/entity-retrieval", headers=headers, params=params).json()
#      <a href='vscode-notebook-cell://attached-container%2B7b22636f6e7461696e65724e616d65223a222f7374695f6c6c6d5f6a757079746572227d@ssh-remote%2B74.234.142.60/home/jovyan/work/datasets/dataset_jupyter.ipynb#X10sdnNjb2RlLXJlbW90ZQ%3D%3D?line=22'>23</a> for key, value in result.items():
#      <a href='vscode-notebook-cell://attached-container%2B7b22636f6e7461696e65724e616d65223a222f7374695f6c6c6d5f6a757079746572227d@ssh-remote%2B74.234.142.60/home/jovyan/work/datasets/dataset_jupyter.ipynb#X10sdnNjb2RlLXJlbW90ZQ%3D%3D?line=23'>24</a>     current_lookup_result = {"name": key, "entities": []}
#
# File /opt/conda/lib/python3.11/site-packages/requests/api.py:73, in get(url, params, **kwargs)
#      62 def get(url, params=None, **kwargs):
#      63     r"""Sends a GET request.
#      64
#      65     :param url: URL for the new :class:`Request` object.
#    (...)
#      70     :rtype: requests.Response
#      71     """
# ---> 73     return request("get", url, params=params, **kwargs)
#
# File /opt/conda/lib/python3.11/site-packages/requests/api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
#      56 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      57 # cases, and look like a memory leak in others.
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File /opt/conda/lib/python3.11/site-packages/requests/sessions.py:575, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     562 # Create the Request.
#     563 req = Request(
#     564     method=method.upper(),
#     565     url=url,
#    (...)
#     573     hooks=hooks,
#     574 )
# --> 575 prep = self.prepare_request(req)
#     577 proxies = proxies or {}
#     579 settings = self.merge_environment_settings(
#     580     prep.url, proxies, stream, verify, cert
#     581 )
#
# File /opt/conda/lib/python3.11/site-packages/requests/sessions.py:486, in Session.prepare_request(self, request)
#     483     auth = get_netrc_auth(request.url)
#     485 p = PreparedRequest()
# --> 486 p.prepare(
#     487     method=request.method.upper(),
#     488     url=request.url,
#     489     files=request.files,
#     490     data=request.data,
#     491     json=request.json,
#     492     headers=merge_setting(
#     493         request.headers, self.headers, dict_class=CaseInsensitiveDict
#     494     ),
#     495     params=merge_setting(request.params, self.params),
#     496     auth=merge_setting(auth, self.auth),
#     497     cookies=merged_cookies,
#     498     hooks=merge_hooks(request.hooks, self.hooks),
#     499 )
#     500 return p
#
# File /opt/conda/lib/python3.11/site-packages/requests/models.py:369, in PreparedRequest.prepare(self, method, url, headers, files, data, params, auth, cookies, hooks, json)
#     367 self.prepare_method(method)
#     368 self.prepare_url(url, params)
# --> 369 self.prepare_headers(headers)
#     370 self.prepare_cookies(cookies)
#     371 self.prepare_body(data, files, json)
#
# File /opt/conda/lib/python3.11/site-packages/requests/models.py:487, in PreparedRequest.prepare_headers(self, headers)
#     484 def prepare_headers(self, headers):
#     485     """Prepares the given HTTP headers."""
# --> 487     self.headers = CaseInsensitiveDict()
#     488     if headers:
#     489         for header in headers.items():
#     490             # Raise exception on invalid header value.
#
# File /opt/conda/lib/python3.11/site-packages/requests/structures.py:44, in CaseInsensitiveDict.__init__(self, data, **kwargs)
#      42 if data is None:
#      43     data = {}
# ---> 44 self.update(data, **kwargs)
#
# File <frozen _collections_abc>:947, in update(self, other, **kwds)
#
# File <frozen abc>:117, in __instancecheck__(cls, instance)
#
# KeyboardInterrupt:

# %%
len(cell_set)
result = lookup(list(cell_set)[0:50])
print(result)
# Out:
# [{'name': '1958 okolo slovenska', 'entities': [{'id': 'Q62123884', 'label': '1958 Okolo Slovenska'}, {'id': 'Q62123881', 'label': 'Okolo Slovenska 1955'}, {'id': 'Q62123887', 'label': 'Okolo Slovenska 1960'}, {'id': 'Q62123892', 'label': '1967 Okolo Slovenska'}, {'id': 'Q62123899', 'label': 'Okolo Slovenska 1975'}, {'id': 'Q62123902', 'label': 'Okolo Slovenska 1978'}, {'id': 'Q62123903', 'label': '1979 Okolo Slovenska'}, {'id': 'Q62123908', 'label': '1984 Okolo Slovenska'}]}, {'name': '1980 école militaire shooting', 'entities': [{'id': 'Q32354721', 'label': '1980 École Militaire shooting'}, {'id': 'Q273480', 'label': 'École Militaire'}, {'id': 'Q273476', 'label': 'École Militaire'}, {'id': 'Q1132066', 'label': 'École spéciale militaire'}, {'id': 'Q718869', 'label': 'École militaire Nunziatella'}, {'id': 'Q1515214', 'label': 'École royale militaire'}, {'id': 'Q3392821', 'label': 'École Navale Militaire'}, {'id': 'Q3953343', 'label': 'École militaire Teulié'}]}, {'name': 'augusta-richmond county public library system', 'entities': [{'id': 'Q30267984', 'label': 'Augusta-Richmond County Public Library System'}, {'id': 'Q77062475', 'label': 'Augusta-Richmond County Public Library'}, {'id': 'Q87483663', 'label': 'Augusta-Richmond County Public Library Georgia Heritage Room'}, {'id': 'Q5243945', 'label': 'DeKalb County Public Library System'}, {'id': 'Q5623669', 'label': 'Gwinnett County Public Library System'}, {'id': 'Q35188703', 'label': 'Hernando County Public Library System'}, {'id': 'Q35189106', 'label': 'Levy County Public Library System'}, {'id': 'Q69471297', 'label': 'Coweta County Public Library System'}, {'id': 'Q69471151', 'label': 'Washington County Public Library System'}, {'id': 'Q69481499', 'label': 'Carroll County Public Library System'}]}, {'name': 'aveiro', 'entities': [{'id': 'Q210527', 'label': 'Aveiro'}, {'id': 'Q1187124', 'label': 'Aveiro'}, {'id': 'Q485581', 'label': 'Aveiro'}, {'id': 'Q790342', 'label': 'Aveiro'}, {'id': 'Q56240874', 'label': 'Aveiro'}, {'id': 'Q22066935', 'label': 'Aveiro'}, {'id': 'Q59661572', 'label': 'Aveiro'}, {'id': 'Q37487459', 'label': 'Aveiro'}]}, {'name': 'baldwin county', 'entities': [{'id': 'Q156163', 'label': 'Baldwin County'}, {'id': 'Q488206', 'label': 'Baldwin County'}, {'id': 'Q4850534', 'label': 'Baldwin County Airport'}, {'id': 'Q107167077', 'label': 'Baldwin County Commission'}, {'id': 'Q1776538', 'label': 'Baldwin Township, Allegheny County'}, {'id': 'Q4850535', 'label': 'Baldwin County Public Schools'}]}, {'name': 'baraboo', 'entities': [{'id': 'Q4858091', 'label': 'Baraboo'}, {'id': 'Q1023544', 'label': 'Baraboo'}, {'id': 'Q112634152', 'label': 'Baraboo'}, {'id': 'Q2658780', 'label': 'Baraboo'}, {'id': 'Q2147674', 'label': 'Baraboo Range'}, {'id': 'Q1860339', 'label': 'Tây Baraboo'}]}, {'name': 'baumkirchen', 'entities': [{'id': 'Q667498', 'label': 'Baumkirchen'}, {'id': 'Q47512894', 'label': 'Baumkirchen'}, {'id': 'Q21881892', 'label': 'Baumkirchen'}, {'id': 'Q97156437', 'label': 'Feuerwehrhaus Baumkirchen'}, {'id': 'Q17326074', 'label': 'Schloss Baumkirchen'}, {'id': 'Q117089369', 'label': 'Baumkirchen Mitte'}, {'id': 'Q38064470', 'label': 'Widum Baumkirchen'}, {'id': 'Q98740520', 'label': 'Friedhof Baumkirchen'}, {'id': 'Q4847311', 'label': 'Šabluons:Delete'}]}, {'name': 'birmingham', 'entities': [{'id': 'Q865761', 'label': 'Birmingham'}, {'id': 'Q593324', 'label': 'Birmingham'}, {'id': 'Q865725', 'label': 'Birmingham'}, {'id': 'Q1922603', 'label': 'Birmingham'}, {'id': 'Q2188746', 'label': 'Birmingham'}, {'id': 'Q368323', 'label': 'Birmingham'}, {'id': 'Q4916568', 'label': 'Birmingham'}, {'id': 'Q4916574', 'label': 'Birmingham'}, {'id': 'Q20986424', 'label': 'Birmingham'}, {'id': 'Q4916577', 'label': 'Birmingham'}]}, {'name': 'branco mello', 'entities': [{'id': 'Q4956461', 'label': 'Branco Mello'}, {'id': 'Q39701', 'label': 'Mello'}, {'id': 'Q917944', 'label': 'Mello'}, {'id': 'Q1060178', 'label': 'Mello'}, {'id': 'Q18504272', 'label': 'Mello'}, {'id': 'Q36953649', ...

# %%
all_datasets: list[dict[str, str]] = []
for dataset in tqdm(cea_datasets):
    print(f"{dataset['dataset']}...")
    gt_dataset = GroundTruthCEA(dataset['gt'])
    gt_dataset.load()

    dataset = Dataset(gt_dataset, dataset['dataset'], dataset['tables'])
    dataset.load_tables()
    all_datasets.extend(dataset.llm_dataset)

len(all_datasets)
# Out:
#   0%|          | 0/7 [00:00<?, ?it/s]
# semtab_2020_r1...
# Loading ground truth...
# Total lines: 985110
# 100%|██████████| 985110/985110 [00:02<00:00, 431382.03it/s]
# LOAD TABLES...
#   0%|          | 1/985110 [00:03<995:12:37,  3.64s/it]
#   0%|          | 0/7 [00:06<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /home/jovyan/work/datasets/dataset_jupyter.ipynb Cella 7 line 8
#       <a href='vscode-notebook-cell://attached-container%2B7b22636f6e7461696e65724e616d65223a222f7374695f6c6c6d5f6a757079746572227d@ssh-remote%2B74.234.142.60/home/jovyan/work/datasets/dataset_jupyter.ipynb#W6sdnNjb2RlLXJlbW90ZQ%3D%3D?line=4'>5</a> gt_dataset.load()
#       <a href='vscode-notebook-cell://attached-container%2B7b22636f6e7461696e65724e616d65223a222f7374695f6c6c6d5f6a757079746572227d@ssh-remote%2B74.234.142.60/home/jovyan/work/datasets/dataset_jupyter.ipynb#W6sdnNjb2RlLXJlbW90ZQ%3D%3D?line=6'>7</a> dataset = Dataset(gt_dataset, dataset['dataset'], dataset['tables'])
# ----> <a href='vscode-notebook-cell://attached-container%2B7b22636f6e7461696e65724e616d65223a222f7374695f6c6c6d5f6a757079746572227d@ssh-remote%2B74.234.142.60/home/jovyan/work/datasets/dataset_jupyter.ipynb#W6sdnNjb2RlLXJlbW90ZQ%3D%3D?line=7'>8</a> dataset.load_tables()
#       <a href='vscode-notebook-cell://attached-container%2B7b22636f6e7461696e65724e616d65223a222f7374695f6c6c6d5f6a757079746572227d@ssh-remote%2B74.234.142.60/home/jovyan/work/datasets/dataset_jupyter.ipynb#W6sdnNjb2RlLXJlbW90ZQ%3D%3D?line=8'>9</a> len(dataset.llm_dataset)
#      <a href='vscode-notebook-cell://attached-container%2B7b22636f6e7461696e65724e616d65223a222f7374695f6c6c6d5f6a757079746572227d@ssh-remote%2B74.234.142.60/home/jovyan/work/datasets/dataset_jupyter.ipynb#W6sdnNjb2RlLXJlbW90ZQ%3D%3D?line=9'>10</a> all_datasets.extend(dataset.llm_dataset)
#
# /home/jovyan/work/datasets/dataset_jupyter.ipynb Cella 7 line 1
#     <a href='vscode-notebook-cell://attached-container%2B7b22636f6e7461696e65724e616d65223a222f7374695f6c6c6d5f6a757079746572227d@ssh-remote%2B74.234.142.60/home/jovyan/work/datasets/dataset_jupyter.ipynb#W6sdnNjb2RlLXJlbW90ZQ%3D%3D?line=139'>140</a>     table_representation += ";".join(row) + "|"
#     <a href='vscode-notebook-cell://attached-container%2B7b22636f6e7461696e65724e616d65223a222f7374695f6c6c6d5f6a757079746572227d@ssh-remote%2B74.234.142.60/home/jovyan/work/datasets/dataset_jupyter.ipynb#W6sdnNjb2RlLXJlbW90ZQ%3D%3D?line=140'>141</a> table_representation = table_representation[:-1]
# --> <a href='vscode-notebook-cell://attached-container%2B7b22636f6e7461696e65724e616d65223a222f7374695f6c6c6d5f6a757079746572227d@ssh-remote%2B74.234.142.60/home/jovyan/work/datasets/dataset_jupyter.ipynb#W6sdnNjb2RlLXJlbW90ZQ%3D%3D?line=141'>142</a> pool = self.get_pool(table_representation)
#     <a href='vscode-notebook-cell://attached-container%2B7b22636f6e7461696e65724e616d65223a222f7374695f6c6c6d5f6a757079746572227d@ssh-remote%2B74.234.142.60/home/jovyan/work/datasets/dataset_jupyter.ipynb#W6sdnNjb2RlLXJlbW90ZQ%3D%3D?line=142'>143</a> current_output = self.get_output(table_name)
#     <a href='vscode-notebook-cell://attached-container%2B7b22636f6e7461696e65724e616d65223a222f7374695f6c6c6d5f6a757079746572227d@ssh-remote%2B74.234.142.60/home/jovyan/work/datasets/dataset_jupyter.ipynb#W6sdnNjb2RlLXJlbW90ZQ%3D%3D?line=143'>144</a> if current_output is None:
#
# /home/jovyan/work/datasets/dataset_jupyter.ipynb Cella 7 line 1
#     <a href='vscode-notebook-cell://attached-container%2B7b22636f6e7461696e65724e616d65223a222f7374695f6c6c6d5f6a757079746572227d@ssh-remote%2B74.234.142.60/home/jovyan/work/datasets/dataset_jupyter.ipynb#W6sdnNjb2RlLXJlbW90ZQ%3D%3D?line=99'>100</a>         pool.add(f"{entity['id']} [{entity['label']}]")
#     <a href='vscode-notebook-cell://attached-container%2B7b22636f6e7461696e65724e616d65223a222f7374695f6c6c6d5f6a757079746572227d@ssh-remote%2B74.234.142.60/home/jovyan/work/datasets/dataset_jupyter.ipynb#W6sdnNjb2RlLXJlbW90ZQ%3D%3D?line=100'>101</a>     continue
# --> <a href='vscode-notebook-cell://attached-container%2B7b22636f6e7461696e65724e616d65223a222f7374695f6c6c6d5f6a757079746572227d@ssh-remote%2B74.234.142.60/home/jovyan/work/datasets/dataset_jupyter.ipynb#W6sdnNjb2RlLXJlbW90ZQ%3D%3D?line=101'>102</a> lookup_response = lookup(cell)
#     <a href='vscode-notebook-cell://attached-container%2B7b22636f6e7461696e65724e616d65223a222f7374695f6c6c6d5f6a757079746572227d@ssh-remote%2B74.234.142.60/home/jovyan/work/datasets/dataset_jupyter.ipynb#W6sdnNjb2RlLXJlbW90ZQ%3D%3D?line=102'>103</a> if len(lookup_response) > 0:
#     <a href='vscode-notebook-cell://attached-container%2B7b22636f6e7461696e65724e616d65223a222f7374695f6c6c6d5f6a757079746572227d@ssh-remote%2B74.234.142.60/home/jovyan/work/datasets/dataset_jupyter.ipynb#W6sdnNjb2RlLXJlbW90ZQ%3D%3D?line=103'>104</a>     for entity in lookup_response:
#
# /home/jovyan/work/datasets/dataset_jupyter.ipynb Cella 7 line 1
#       <a href='vscode-notebook-cell://attached-container%2B7b22636f6e7461696e65724e616d65223a222f7374695f6c6c6d5f6a757079746572227d@ssh-remote%2B74.234.142.60/home/jovyan/work/datasets/dataset_jupyter.ipynb#W6sdnNjb2RlLXJlbW90ZQ%3D%3D?line=7'>8</a> lookup_response = []
#       <a href='vscode-notebook-cell://attached-container%2B7b22636f6e7461696e65724e616d65223a222f7374695f6c6c6d5f6a757079746572227d@ssh-remote%2B74.234.142.60/home/jovyan/work/datasets/dataset_jupyter.ipynb#W6sdnNjb2RlLXJlbW90ZQ%3D%3D?line=8'>9</a> params = {
#      <a href='vscode-notebook-cell://attached-container%2B7b22636f6e7461696e65724e616d65223a222f7374695f6c6c6d5f6a757079746572227d@ssh-remote%2B74.234.142.60/home/jovyan/work/datasets/dataset_jupyter.ipynb#W6sdnNjb2RlLXJlbW90ZQ%3D%3D?line=9'>10</a>     'token': "insideslab-lamapi-2022",
#      <a href='vscode-notebook-cell://attached-container%2B7b22636f6e7461696e65724e616d65223a222f7374695f6c6c6d5f6a757079746572227d@ssh-remote%2B74.234.142.60/home/jovyan/work/datasets/dataset_jupyter.ipynb#W6sdnNjb2RlLXJlbW90ZQ%3D%3D?line=10'>11</a>     'name': cell,
#      <a href='vscode-notebook-cell://attached-container%2B7b22636f6e7461696e65724e616d65223a222f7374695f6c6c6d5f6a757079746572227d@ssh-remote%2B74.234.142.60/home/jovyan/work/datasets/dataset_jupyter.ipynb#W6sdnNjb2RlLXJlbW90ZQ%3D%3D?line=11'>12</a>     'kg': "wikidata",
#      <a href='vscode-notebook-cell://attached-container%2B7b22636f6e7461696e65724e616d65223a222f7374695f6c6c6d5f6a757079746572227d@ssh-remote%2B74.234.142.60/home/jovyan/work/datasets/dataset_jupyter.ipynb#W6sdnNjb2RlLXJlbW90ZQ%3D%3D?line=12'>13</a>     'limit': 5
#      <a href='vscode-notebook-cell://attached-container%2B7b22636f6e7461696e65724e616d65223a222f7374695f6c6c6d5f6a757079746572227d@ssh-remote%2B74.234.142.60/home/jovyan/work/datasets/dataset_jupyter.ipynb#W6sdnNjb2RlLXJlbW90ZQ%3D%3D?line=13'>14</a> }
# ---> <a href='vscode-notebook-cell://attached-container%2B7b22636f6e7461696e65724e616d65223a222f7374695f6c6c6d5f6a757079746572227d@ssh-remote%2B74.234.142.60/home/jovyan/work/datasets/dataset_jupyter.ipynb#W6sdnNjb2RlLXJlbW90ZQ%3D%3D?line=14'>15</a> result = requests.get("https://lamapi.inside.disco.unimib.it/lookup/entity-retrieval", headers=headers, params=params).json()
#      <a href='vscode-notebook-cell://attached-container%2B7b22636f6e7461696e65724e616d65223a222f7374695f6c6c6d5f6a757079746572227d@ssh-remote%2B74.234.142.60/home/jovyan/work/datasets/dataset_jupyter.ipynb#W6sdnNjb2RlLXJlbW90ZQ%3D%3D?line=15'>16</a> if len(result[cell.lower()]) > 0:
#      <a href='vscode-notebook-cell://attached-container%2B7b22636f6e7461696e65724e616d65223a222f7374695f6c6c6d5f6a757079746572227d@ssh-remote%2B74.234.142.60/home/jovyan/work/datasets/dataset_jupyter.ipynb#W6sdnNjb2RlLXJlbW90ZQ%3D%3D?line=16'>17</a>     for entity in result[cell.lower()]:
#
# File /opt/conda/lib/python3.11/site-packages/requests/api.py:73, in get(url, params, **kwargs)
#      62 def get(url, params=None, **kwargs):
#      63     r"""Sends a GET request.
#      64
#      65     :param url: URL for the new :class:`Request` object.
#    (...)
#      70     :rtype: requests.Response
#      71     """
# ---> 73     return request("get", url, params=params, **kwargs)
#
# File /opt/conda/lib/python3.11/site-packages/requests/api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
#      56 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      57 # cases, and look like a memory leak in others.
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File /opt/conda/lib/python3.11/site-packages/requests/sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File /opt/conda/lib/python3.11/site-packages/requests/sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File /opt/conda/lib/python3.11/site-packages/requests/adapters.py:486, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     483     timeout = TimeoutSauce(connect=timeout, read=timeout)
#     485 try:
# --> 486     resp = conn.urlopen(
#     487         method=request.method,
#     488         url=url,
#     489         body=request.body,
#     490         headers=request.headers,
#     491         redirect=False,
#     492         assert_same_host=False,
#     493         preload_content=False,
#     494         decode_content=False,
#     495         retries=self.max_retries,
#     496         timeout=timeout,
#     497         chunked=chunked,
#     498     )
#     500 except (ProtocolError, OSError) as err:
#     501     raise ConnectionError(err, request=request)
#
# File /opt/conda/lib/python3.11/site-packages/urllib3/connectionpool.py:791, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     788 response_conn = conn if not release_conn else None
#     790 # Make the request on the HTTPConnection object
# --> 791 response = self._make_request(
#     792     conn,
#     793     method,
#     794     url,
#     795     timeout=timeout_obj,
#     796     body=body,
#     797     headers=headers,
#     798     chunked=chunked,
#     799     retries=retries,
#     800     response_conn=response_conn,
#     801     preload_content=preload_content,
#     802     decode_content=decode_content,
#     803     **response_kw,
#     804 )
#     806 # Everything went great!
#     807 clean_exit = True
#
# File /opt/conda/lib/python3.11/site-packages/urllib3/connectionpool.py:468, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     465 try:
#     466     # Trigger any extra validation we need to do.
#     467     try:
# --> 468         self._validate_conn(conn)
#     469     except (SocketTimeout, BaseSSLError) as e:
#     470         self._raise_timeout(err=e, url=url, timeout_value=conn.timeout)
#
# File /opt/conda/lib/python3.11/site-packages/urllib3/connectionpool.py:1097, in HTTPSConnectionPool._validate_conn(self, conn)
#    1095 # Force connect early to allow us to validate the connection.
#    1096 if conn.is_closed:
# -> 1097     conn.connect()
#    1099 if not conn.is_verified:
#    1100     warnings.warn(
#    1101         (
#    1102             f"Unverified HTTPS request is being made to host '{conn.host}'. "
#    (...)
#    1107         InsecureRequestWarning,
#    1108     )
#
# File /opt/conda/lib/python3.11/site-packages/urllib3/connection.py:642, in HTTPSConnection.connect(self)
#     633 if is_time_off:
#     634     warnings.warn(
#     635         (
#     636             f"System time is way off (before {RECENT_DATE}). This will probably "
#    (...)
#     639         SystemTimeWarning,
#     640     )
# --> 642 sock_and_verified = _ssl_wrap_socket_and_match_hostname(
#     643     sock=sock,
#     644     cert_reqs=self.cert_reqs,
#     645     ssl_version=self.ssl_version,
#     646     ssl_minimum_version=self.ssl_minimum_version,
#     647     ssl_maximum_version=self.ssl_maximum_version,
#     648     ca_certs=self.ca_certs,
#     649     ca_cert_dir=self.ca_cert_dir,
#     650     ca_cert_data=self.ca_cert_data,
#     651     cert_file=self.cert_file,
#     652     key_file=self.key_file,
#     653     key_password=self.key_password,
#     654     server_hostname=server_hostname,
#     655     ssl_context=self.ssl_context,
#     656     tls_in_tls=tls_in_tls,
#     657     assert_hostname=self.assert_hostname,
#     658     assert_fingerprint=self.assert_fingerprint,
#     659 )
#     660 self.sock = sock_and_verified.socket
#     661 self.is_verified = sock_and_verified.is_verified
#
# File /opt/conda/lib/python3.11/site-packages/urllib3/connection.py:783, in _ssl_wrap_socket_and_match_hostname(sock, cert_reqs, ssl_version, ssl_minimum_version, ssl_maximum_version, cert_file, key_file, key_password, ca_certs, ca_cert_dir, ca_cert_data, assert_hostname, assert_fingerprint, server_hostname, ssl_context, tls_in_tls)
#     780     if is_ipaddress(normalized):
#     781         server_hostname = normalized
# --> 783 ssl_sock = ssl_wrap_socket(
#     784     sock=sock,
#     785     keyfile=key_file,
#     786     certfile=cert_file,
#     787     key_password=key_password,
#     788     ca_certs=ca_certs,
#     789     ca_cert_dir=ca_cert_dir,
#     790     ca_cert_data=ca_cert_data,
#     791     server_hostname=server_hostname,
#     792     ssl_context=context,
#     793     tls_in_tls=tls_in_tls,
#     794 )
#     796 try:
#     797     if assert_fingerprint:
#
# File /opt/conda/lib/python3.11/site-packages/urllib3/util/ssl_.py:471, in ssl_wrap_socket(sock, keyfile, certfile, cert_reqs, ca_certs, server_hostname, ssl_version, ciphers, ssl_context, ca_cert_dir, key_password, ca_cert_data, tls_in_tls)
#     468 except NotImplementedError:  # Defensive: in CI, we always have set_alpn_protocols
#     469     pass
# --> 471 ssl_sock = _ssl_wrap_socket_impl(sock, context, tls_in_tls, server_hostname)
#     472 return ssl_sock
#
# File /opt/conda/lib/python3.11/site-packages/urllib3/util/ssl_.py:515, in _ssl_wrap_socket_impl(sock, ssl_context, tls_in_tls, server_hostname)
#     512     SSLTransport._validate_ssl_context_for_tls_in_tls(ssl_context)
#     513     return SSLTransport(sock, ssl_context, server_hostname)
# --> 515 return ssl_context.wrap_socket(sock, server_hostname=server_hostname)
#
# File /opt/conda/lib/python3.11/ssl.py:517, in SSLContext.wrap_socket(self, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname, session)
#     511 def wrap_socket(self, sock, server_side=False,
#     512                 do_handshake_on_connect=True,
#     513                 suppress_ragged_eofs=True,
#     514                 server_hostname=None, session=None):
#     515     # SSLSocket class handles server_hostname encoding before it calls
#     516     # ctx._wrap_socket()
# --> 517     return self.sslsocket_class._create(
#     518         sock=sock,
#     519         server_side=server_side,
#     520         do_handshake_on_connect=do_handshake_on_connect,
#     521         suppress_ragged_eofs=suppress_ragged_eofs,
#     522         server_hostname=server_hostname,
#     523         context=self,
#     524         session=session
#     525     )
#
# File /opt/conda/lib/python3.11/ssl.py:1108, in SSLSocket._create(cls, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname, context, session)
#    1105         if timeout == 0.0:
#    1106             # non-blocking
#    1107             raise ValueError("do_handshake_on_connect should not be specified for non-blocking sockets")
# -> 1108         self.do_handshake()
#    1109 except (OSError, ValueError):
#    1110     self.close()
#
# File /opt/conda/lib/python3.11/ssl.py:1379, in SSLSocket.do_handshake(self, block)
#    1377     if timeout == 0.0 and block:
#    1378         self.settimeout(None)
# -> 1379     self._sslobj.do_handshake()
#    1380 finally:
#    1381     self.settimeout(timeout)
#
# KeyboardInterrupt:

# %%
all_datasets
# Out:
# []

# %%
def to_jsonl(llm_dataset_list: list, datasetName: str):
    with open(datasetName, 'w') as outfile:
        for entry in llm_dataset_list:
            json.dump(entry, outfile)
            outfile.write('\n')

# %%
to_jsonl(all_datasets, 'output/cea_all.jsonl')

# %% [markdown]
# ## CTA

# %%
class GroundTruthItemCTA:
    def __init__(self, table, column, value):
        self.table: str = table
        self.column: str = column
        self.value: str = value

    def get_item(self) -> dict[str, str]:
        return {
            'table': self.table,
            'column': self.column,
        }
    
    @property
    def get_identifier(self) -> str:
        return f'{self.column}'
    
    @property
    def get_output(self) -> str:
        return f'({self.column})={self.value}'

    def __str__(self) -> str:
        return f'{self.table} {self.column} {self.value}'
    
class GroundTruthCTA:

    def __init__(self, filename):
        self.filename: str = filename
        self.ground_truth: dict[str, dict[str, GroundTruthItemCTA]] = {}

    @property
    def total(self) -> int:
        return len(self.ground_truth)
    
    def number_of_items_in_csv(self) -> int:
        with open(self.filename, 'r') as f:
            reader = csv.reader(f)
            total: int = 0
            for _ in reader:
                total += 1
            return total

    def load(self):
        with open(self.filename, 'r') as f:
            print('Loading ground truth...')
            total_lines: int = self.number_of_items_in_csv()
            print(f'Total lines: {total_lines}')
            reader = csv.reader(f)
            for row in tqdm(reader, total=total_lines):
                current_gt: GroundTruthItemCTA = GroundTruthItemCTA(row[0], row[1], row[2])
                if current_gt.table in self.ground_truth:
                    self.ground_truth[current_gt.table][current_gt.get_identifier] = current_gt
                else:
                    self.ground_truth[current_gt.table] = {
                        current_gt.get_identifier: current_gt
                    }

class DatasetCTA():

    def __init__(self, gt_dataset: GroundTruthCTA, filename: str):
        self.filename: str = filename
        self.gt_dataset = gt_dataset
        self.llm_dataset: list[dict[str, str]] = []
        self.instruction = "perform the column type annotation (cta) task on this table:"

    def get_output(self, table_name: str) -> str | None:
        outputCTA: str = ""
        if table_name not in self.gt_dataset.ground_truth:
            return None
        for _, gtTable in self.gt_dataset.ground_truth[table_name].items():
            if gtTable.value != "UNKNOWN":
                outputCTA += gtTable.get_output.replace('http://www.wikidata.org/entity/', '') + "|"
            else:
                return None

        return outputCTA

    def load_tables(self):
        all_csv_tables = os.listdir(self.filename)
        for csv_table in tqdm(all_csv_tables, total=len(all_csv_tables)):
            table_name: str = csv_table.split('.')[0]
            table_representation: str = ""
            with open(os.path.join(self.filename, csv_table), 'r') as f:
                reader = csv.reader(f)
                next(reader, None)
                for row in reader:
                    table_representation += ";".join(row) + "|"
                current_output = self.get_output(table_name)
                if current_output is None:
                    continue
                self.llm_dataset.append({
                    'table': table_name,
                    'instruction': self.instruction,
                    'input': table_representation,
                    "output": current_output
                })

# %%
# Mammotab CTA
path = './wikidata/mammotab_dataset_semtab/gt/CTA_mammotab_gt.csv'
gt_dataset_mammotab_cta = GroundTruthCTA(path)
gt_dataset_mammotab_cta.load()

dataset_cta_mammotab = DatasetCTA(gt_dataset_mammotab_cta, './wikidata/mammotab_dataset_semtab/tables')
dataset_cta_mammotab.load_tables()
len(dataset_cta_mammotab.llm_dataset)
# Out:
# Loading ground truth...
# Total lines: 5541283
# 100%|██████████| 5541283/5541283 [00:08<00:00, 673977.94it/s]
# 100%|██████████| 980254/980254 [04:45<00:00, 3436.42it/s]
# 6502

# %%
dataset_cta_mammotab.llm_dataset[0]
# Out:
# {'table': 'RSDLDEWR',
#  'instruction': 'perform the column type annotation (cta) task on this table:',
#  'input': 'Corey Peters;NT;Arizona Cardinals|Steven Means;DE;Atlanta Falcons|Bradley Bozeman;G;Baltimore Ravens|Harrison Phillips;DT;Buffalo Bills|Shaq Thompson;LB;Carolina Panthers|Jimmy Graham;TE;Chicago Bears|Geno Atkins;DT;Cincinnati Bengals|Myles Garrett;DE;Cleveland Browns|Jaylon Smith;LB;Dallas Cowboys|Justin Simmons;FS;Denver Broncos|Trey Flowers;DE;Detroit Lions|Corey Linsley;C;Green Bay Packers|Michael Thomas;FS;Houston Texans|Jacoby Brissett;QB;Indianapolis Colts|Josh Lambo;K;Jacksonville Jaguars|Travis Kelce;TE;Kansas City Chiefs|Alec Ingold;FB;Las Vegas Raiders|Isaac Rochell;DE;Los Angeles Chargers|Andrew Whitworth;OT;Los Angeles Rams|Byron Jones;CB;Miami Dolphins|Eric Kendricks;LB;Minnesota Vikings|Devin McCourty;FS;New England Patriots|Demario Davis;LB;New Orleans Saints|Dalvin Tomlinson;NT;New York Giants|Pierre Desir;CB;New York Jets|Rodney McLeod;S;Philadelphia Eagles|Vance McDonald;TE;Pittsburgh Steelers|Arik Armstead;DE;San Francisco 49ers|Russell Wilson]];QB;Seattle Seahawks|Mike Evans;WR;Tampa Bay Buccaneers|Kevin Byard;S;Tennessee Titans|Jonathan Allen;DT;Washington Football Team|Source:;Source:;Source:|',
#  'output': '(0)=Q19204627|(1)=Q694589|(2)=Q17156793|'}

# %% [markdown]
# ## CPA

# %%
class GroundTruthItemCPA:
    def __init__(self, table, col_1, col_2, value):
        self.table: str = table
        self.col_1: str = col_1
        self.col_2: str = col_2
        self.value: str = value

    def get_item(self) -> dict[str, str]:
        return {
            'table': self.table,
            'col_1': self.col_1,
            'col_2': self.col_2,
        }
    
    @property
    def get_identifier(self) -> str:
        return f'{self.col_1}_{self.col_2}'
    
    @property
    def get_output(self) -> str:
        return f'({self.col_1},{self.col_2})={self.value}'

    def __str__(self) -> str:
        return f'{self.table} {self.col_1} {self.col_2} {self.value}'
    
class GroundTruthCPA:

    def __init__(self, filename):
        self.filename: str = filename
        self.ground_truth: dict[str, dict[str, GroundTruthItemCPA]] = {}

    @property
    def total(self) -> int:
        return len(self.ground_truth)
    
    def number_of_items_in_csv(self) -> int:
        with open(self.filename, 'r') as f:
            reader = csv.reader(f)
            total: int = 0
            for _ in reader:
                total += 1
            return total

    def load(self):
        with open(self.filename, 'r') as f:
            print('Loading ground truth...')
            total_lines: int = self.number_of_items_in_csv()
            print(f'Total lines: {total_lines}')
            reader = csv.reader(f)
            for row in tqdm(reader, total=total_lines):
                current_gt: GroundTruthItemCPA = GroundTruthItemCPA(row[0], row[1], row[2], row[3])
                if current_gt.table in self.ground_truth:
                    self.ground_truth[current_gt.table][current_gt.get_identifier] = current_gt
                else:
                    self.ground_truth[current_gt.table] = {
                        current_gt.get_identifier: current_gt
                    }

class DatasetCPA():

    def __init__(self, gt_dataset: GroundTruthCPA, filename: str):
        self.filename: str = filename
        self.gt_dataset = gt_dataset
        self.llm_dataset: list[dict[str, str]] = []
        self.instruction = "perform the column property annotation (cpa) task on this table:"

    def get_output(self, table_name: str) -> str | None:
        outputCTA: str = ""
        if table_name not in self.gt_dataset.ground_truth:
            return None
        for _, gtTable in self.gt_dataset.ground_truth[table_name].items():
            if gtTable.value != "UNKNOWN":
                outputCTA += gtTable.get_output.replace('http://www.wikidata.org/entity/', '') + "|"
            else:
                return None

        return outputCTA

    def load_tables(self):
        all_csv_tables = os.listdir(self.filename)
        for csv_table in tqdm(all_csv_tables, total=len(all_csv_tables)):
            table_name: str = csv_table.split('.')[0]
            table_representation: str = ""
            with open(os.path.join(self.filename, csv_table), 'r') as f:
                reader = csv.reader(f)
                next(reader, None)
                for row in reader:
                    table_representation += ";".join(row) + "|"
                current_output = self.get_output(table_name)
                if current_output is None:
                    continue
                self.llm_dataset.append({
                    'table': table_name,
                    'instruction': self.instruction,
                    'input': table_representation,
                    "output": current_output
                })

# %% [markdown]
# ## Pool Dataset

# %%
import os
import csv
import json
import random
from tqdm import tqdm

# %%
from pymongo import MongoClient

import os

MONGO_ENDPOINT = os.environ['MONGO_ENDPOINT']
MONGO_PORT = os.environ['MONGO_PORT']
MONGO_ENDPOINT_USERNAME = os.environ['MONGO_INITDB_ROOT_USERNAME']
MONGO_ENDPOINT_PASSWORD = os.environ['MONGO_INITDB_ROOT_PASSWORD']
MONGO_DBNAME = os.environ['MONGO_DBNAME']
mongo_client = MongoClient(
                            MONGO_ENDPOINT, 
                            int(MONGO_PORT), 
                            username=MONGO_ENDPOINT_USERNAME, 
                            password=MONGO_ENDPOINT_PASSWORD, 
                            authSource='admin'
                        )

def get_collection(collection_name):
    return mongo_client[MONGO_DBNAME][collection_name]

def get_entity(collection_name, entity):
    return mongo_client[MONGO_DBNAME][collection_name].find_one({ 'entity': entity })

def get_cell_retrieval(collection_name, cell):
    return mongo_client[MONGO_DBNAME][collection_name].find_one({"cell": cell})

# %%
# Literal Recognizer
import re
class LiteralRecognizer():
    
    # PATTERN TO MATCH DATES
    # dates like: '145 bc', '145.bc', '145,bc'
    # dates like: '1997-08-26', '1997.08.26', '1997/08/26'
    # dates like: '26/08/1997', '26.08.1997', '26-08-1997'
    # dates like: '26/08/97', '26.08.97', '26-08-97'
    # dates like: 'august 26 1997', 'august.26.1997', 'august,26,1997'
    # dates like: '26 august 1997', '26.august.1997', '26,august,1997'
    # dates like: '1997 august 26', '1997,august,26', '1997.august.26'
    # dates like: '1997 26 august', '1997,26,august', '1997.26.august'
    # dates like: 'august 1997', 'august.1997', 'august,1997'
    # dates like: '1997 august', '1997.august', '1997,august'
    # numbers like: '2,797,800,564', '2.797.800.564'
    # numbers like: '200,797,800', '200.797.800'
    # numbers like: '2,8', '2.8'
    # date's year: 1997
    # any pure number: 1345, 26, 1, 1990

    DATE_PATTERN = r'^\d{1,4}[\,\.\s\t\n]+bc$|' \
                r'^\d{4}[-.\/]\d{1,2}[-.\/]\d{1,2}$|' \
                r'^\d{1,2}[-.\/]\d{1,2}[-.\/]\d{4}$|' \
                r'^\d{1,2}[-.\/]\d{1,2}[-.\/]\d{2}$|' \
                r'^(january|february|march|april|may|june|july|august|september|october|november|dicember)[\.\,\s\t\n\/]+\d{1,2}[\.\,\s\t\n\/]+\d{4}$|' \
                r'^\d{1,2}[\.\,\s\t\n\/]+(january|february|march|april|may|june|july|august|september|october|november|dicember)[\.\,\s\t\n\/]+\d{4}$|' \
                r'^\d{4}[\.\,\s\t\n\/]+(january|february|march|april|may|june|july|august|september|october|november|dicember)[\.\,\s\t\n\/]+\d{1,2}$|' \
                r'^\d{4}[\.\,\s\t\n\/]+\d{1,2}[\.\,\s\t\n\/]+(january|february|march|april|may|june|july|august|september|october|november|dicember)$|' \
                r'^(january|february|march|april|may|june|july|august|september|october|november|dicember)[\.\,\s\n\t\/]+\d{4}$|' \
                r'^\d{4}[\.\,\s\n\t\/]+(january|february|march|april|may|june|july|august|september|october|november|dicember)$|' \
                r'^\d+[\.\,]\d+[\.\,]\d+[\.\,]\d+$|' \
                r'^\d+[\.\,]\d+[\.\,]\d+$|' \
                r'^\d+[\.\,]\d+$|' \
                r'^\d{4}$|' \
                r'^\d+$'
    
    # PATTERN TO MATCH URLS
    URL_PATTERN = r'^((http|https)\:\/\/)?[a-zA-Z0-9\.\/\?\:@\-_=#]+\.([a-zA-Z]){2,6}([a-zA-Z0-9\.\&\/\?\:@\-_=#])$'
    
    EMAIL_PATTERN = r'^\b[A-Za-z0-9._%+-]+@[A-Za-z0-9.-]+\.[A-Z|a-z]{2,}\b$'
    
    # PATTERN TO MATCH DATETIME
    DATETIME_PATTERN = r'^\d{4}[-.\/]\d{1,2}[-.\/]\d{1,2}T(24:00|2[0-3]:[0-5][0-9]|[0-1][0-9]:[0-5][0-9])$'
    
    # PATTERN TO MATCH TIME
    TIME_PATTERN = r'^(24:00|2[0-3]:[0-5][0-9]|[0-1][0-9]:[0-5][0-9])$'
    
    # PATTERN TO MATCH FLOAT NUMBERS
    FLOAT_NUMBER = r'^[-+]?\d+\.\d+$|' \
                r'^[-+]?\d+\.\d+[eE][-+]\d+$'
    
    # PATTERN TO MATCH INTEGER NUMBERS
    INTEGER_NUMBER = r'^[-+]?\d+$'
    
    datetime_pattern_to_match = re.compile(DATETIME_PATTERN, re.IGNORECASE)
    time_pattern_to_match = re.compile(TIME_PATTERN, re.IGNORECASE)
    date_pattern_to_match = re.compile(DATE_PATTERN, re.IGNORECASE)
    url_pattern_to_match = re.compile(URL_PATTERN, re.IGNORECASE)
    email_pattern_to_match = re.compile(EMAIL_PATTERN, re.IGNORECASE)
    integer_pattern_to_match = re.compile(INTEGER_NUMBER, re.IGNORECASE)
    float_pattern_to_match = re.compile(FLOAT_NUMBER, re.IGNORECASE)
    
    literal_types = {'datetime': datetime_pattern_to_match, 'time': time_pattern_to_match, 'url': url_pattern_to_match, 'email': email_pattern_to_match, 'float': float_pattern_to_match, 'integer': integer_pattern_to_match, 'date': date_pattern_to_match}
    
    @classmethod
    # check literals
    def check_literal(self, token):
        for key in self.literal_types:
            matches = self.literal_types[key].finditer(token)
            list_of_matches = list(matches)
            if len(list_of_matches) > 0:
                return key.upper()
        return 'ENTITY'

# %%
class GroundTruthItemCEA:
    def __init__(self, table, row, column, value):
        self.table: str = table
        self.row: str = row
        self.column: str = column
        self.value: str = value

    def get_item(self) -> dict[str, str]:
        return {
            'table': self.table,
            'row': self.row,
            'column': self.column,
        }
    
    @property
    def get_identifier(self) -> str:
        return f'{self.row}_{self.column}'
    
    @property
    def get_output(self) -> str:
        return f'({self.row},{self.column})={self.value}'

    def __str__(self) -> str:
        return f'{self.table} {self.row} {self.column} {self.value}'
    
class GroundTruthCEA:
    def __init__(self, filename):
        self.filename: str = filename
        self.ground_truth: dict[str, dict[str, GroundTruthItemCEA]] = {}

    @property
    def total(self) -> int:
        return len(self.ground_truth)
    
    def number_of_items_in_csv(self) -> int:
        with open(self.filename, 'r') as f:
            reader = csv.reader(f)
            total: int = 0
            for _ in reader:
                total += 1
            return total

    def load(self):
        with open(self.filename, 'r') as f:
            print('Loading ground truth...')
            total_lines: int = self.number_of_items_in_csv()
            print(f'Total lines: {total_lines}')
            reader = csv.reader(f)
            for row in tqdm(reader, total=total_lines):
                current_gt: GroundTruthItemCEA = GroundTruthItemCEA(row[0], row[1], row[2], row[3])
                if current_gt.table in self.ground_truth:
                    self.ground_truth[current_gt.table][current_gt.get_identifier] = current_gt
                else:
                    self.ground_truth[current_gt.table] = {
                        current_gt.get_identifier: current_gt
                    }

# %%
pool_cache = set()
class Dataset():

    def __init__(self, gt_dataset: GroundTruthCEA, dataset_name: str, filename: str):
        self.filename: str = filename
        self.dataset_name: str = dataset_name
        self.gt_dataset = gt_dataset
        self.llm_dataset: list[dict[str, str]] = []
        self.instruction = "perform the cell entity annotation (cea) task on this table:"
        self.literal_recognizer = LiteralRecognizer()
    
    def get_output(self, table_name: str, pool: set) -> str | None:
        outputCEA: str = ""
        if table_name not in self.gt_dataset.ground_truth:
            return None
        for _, gtTable in self.gt_dataset.ground_truth[table_name].items():
            if gtTable.value != "UNKNOWN":
                current_entity_label = get_entity("entities", gtTable.value.replace('http://www.wikidata.org/entity/', ''))
                if current_entity_label is not None and 'label' in current_entity_label:
                    outputCEA += gtTable.get_output.replace('http://www.wikidata.org/entity/', '') + f" [{current_entity_label['label'].lower()}]" + "|"
                    # add correct entity to pool
                    pool.add(f"{gtTable.value.replace('http://www.wikidata.org/entity/', '')} [{current_entity_label['label'].lower()}]")
                else:
                    outputCEA += gtTable.get_output.replace('http://www.wikidata.org/entity/', '') + "|"
            else:
                return None
        
        return outputCEA, pool
    
    def get_pool(self, filename: str, csv_table: str) -> list[dict[str, str]]:
        pool = set()
        with open(os.path.join(filename, csv_table), 'r') as f:
                reader = csv.reader(f)
                next(reader, None)
                for row in reader:
                    for cell in row:
                        if self.literal_recognizer.check_literal(cell) == "ENTITY":
                            cell_retrieval = get_cell_retrieval("candidate", cell.lower())
                            if cell_retrieval is not None:
                                for entity in cell_retrieval['candidates']['entities'][0:3]:
                                    pool.add(f"{entity['id']} [{entity['label'].lower()}]")
                                    pool_cache.add(f"{entity['id']} [{entity['label'].lower()}]")
                            else:
                                # pescare qualche candidato a caso
                                random_entities = random.sample(list(pool_cache), 3)
                                pool.update(random_entities)
        return pool
    
    def format_pool(self, pool: set) -> str:
        string_pool = ""
        for entity in pool:
            string_pool += entity + ";"
        return string_pool
    
    def load_tables(self):
        all_csv_tables = os.listdir(self.filename)
        print("LOAD TABLES...")
        for csv_table in tqdm(all_csv_tables, total=len(all_csv_tables)):
            table_name: str = csv_table.split('.')[0]
            table_representation: str = ""
            with open(os.path.join(self.filename, csv_table), 'r') as f:
                reader = csv.reader(f)
                next(reader, None)
                for row in reader:
                    table_representation += ";".join(row) + "|"
                table_representation = table_representation[:-1]
                pool = self.get_pool(self.filename, csv_table)
                current_output, pool_updated = self.get_output(table_name, pool)
                if current_output is None:
                    continue
                self.llm_dataset.append({
                    'dataset': self.dataset_name,
                    'table': table_name,
                    'instruction': self.instruction,
                    'input': table_representation,
                    "output": current_output[:-1],
                    "pool_instruction": "use the following pool of entities to annotate the table:",
                    "pool": self.format_pool(pool_updated)
                })

# %%
cea_datasets: list[dict[str, str]] = [
    {"gt": "./wikidata/SemTab2020_Table_GT_Target/GT/CEA/CEA_Round1_gt.csv", "tables": "./wikidata/SemTab2020_Table_GT_Target/Round1/tables", "dataset": "semtab_2020_r1"}, # SemTab2020_Table_GT_Target R1
    {"gt": "./wikidata/SemTab2020_Table_GT_Target/GT/CEA/CEA_Round2_gt.csv", "tables": "./wikidata/SemTab2020_Table_GT_Target/Round2/tables", "dataset": "semtab_2020_r2"}, # SemTab2020_Table_GT_Target R2
    #{"gt": "./wikidata/SemTab2020_Table_GT_Target/GT/CEA/CEA_Round3_gt.csv", "tables": "./wikidata/SemTab2020_Table_GT_Target/Round3/tables", "dataset": "semtab_2020_r3"}, # SemTab2020_Table_GT_Target R3
    {"gt": "./wikidata/SemTab2020_Table_GT_Target/GT/CEA/CEA_Round4_gt.csv", "tables": "./wikidata/SemTab2020_Table_GT_Target/Round4/tables", "dataset": "semtab_2020_r4"}, # SemTab2020_Table_GT_Target R4
    {"gt": "./wikidata/HardTablesR1/DataSets/HardTablesR1/Valid/gt/cea_gt.csv", "tables": "./wikidata/HardTablesR1/DataSets/HardTablesR1/Valid/tables", "dataset": "hardtables_2022_r1"}, # HardTablesR1 2022
    #{"gt": "./wikidata/HardTablesR2/DataSets/HardTablesR2/Valid/gt/cea_gt.csv", "tables": "./wikidata/HardTablesR2/DataSets/HardTablesR2/Valid/tables", "dataset": "hardtables_2022_r2"}, # HardTablesR2 2022
    {"gt": "./wikidata/WikidataTables2023R1/DataSets/Valid/gt/cea_gt.csv", "tables": "./wikidata/WikidataTables2023R1/DataSets/Valid/tables", "dataset": "wikidata_tables_2023"}, # Wikidata Tables 2023
]

# %%
all_datasets: list[dict[str, str]] = []
for dataset in tqdm(cea_datasets):
    print(f"{dataset['dataset']}...")
    gt_dataset = GroundTruthCEA(dataset['gt'])
    gt_dataset.load()

    dataset = Dataset(gt_dataset, dataset['dataset'], dataset['tables'])
    dataset.load_tables()
    all_datasets.extend(dataset.llm_dataset)
# Out:
#   0%|          | 0/2 [00:00<?, ?it/s]
# hardtables_2022_r1...
# Loading ground truth...
# Total lines: 1406
# 100%|██████████| 1406/1406 [00:00<00:00, 749706.51it/s]
# LOAD TABLES...
# 100%|██████████| 200/200 [00:01<00:00, 189.59it/s]
#  50%|█████     | 1/2 [00:01<00:01,  1.06s/it]
# wikidata_tables_2023...
# Loading ground truth...
# Total lines: 4247
# 100%|██████████| 4247/4247 [00:00<00:00, 716713.97it/s]
# LOAD TABLES...
# 100%|██████████| 500/500 [00:03<00:00, 129.02it/s]
# 100%|██████████| 2/2 [00:04<00:00,  2.47s/it]

# %%
dataset.llm_dataset
# Out:
# [{'dataset': 'wikidata_tables_2023',
#   'table': 'NA5XOTEC',
#   'instruction': 'perform the cell entity annotation (cea) task on this table:',
#   'input': 'The Stag Hunt;|Saint Lawrence;|Cain Killing Abel;German Renaissance|Marriage of the Virgin;German Renaissance|Christ on the Mount of Olives;German Renaissance',
#   'output': '(1,0)=Q65511076 [the stag hunt]|(2,0)=Q104154781 [saint lawrence]|(3,0)=Q18339669 [cain killing abel]|(3,1)=Q2455000 [german renaissance]|(4,0)=Q18338565 [marriage of the virgin]|(4,1)=Q2455000 [german renaissance]|(5,0)=Q18339648 [christ on the mount of olives]|(5,1)=Q2455000 [german renaissance]',
#   'pool': 'Q20648159 [no no no];Q26535864 [k6 telephone kiosk outside crown court];Q18339669 [cain killing abel];Q3816474 [korfball at the summer olympics];Q7935239 [virtuoso universal server];Q18338565 [marriage of the virgin];Q613436 [ceti];Q3224308 [marriage of the virgin];Q23785360 [münchen ost rangierbahnhof];Q1243556 [renaissance av renaissance];Q49478020 [chief ouray and chipeta memorial];Q2455000 [german renaissance];Q18508779 [marriage of the virgin];Q4659514 [a silent film];Q68442656 [footbridge bystrc - kníničky];Q105731447 [west virginia];Q11080162 [y. renaissance];Q65511076 [the stag hunt];Q15198572 [bermuda];Q5870918 [history of the single-lens reflex camera];Q115794868 [hyatt regency];Q712868 [red telephone box];Q3291129 [marriage of the virgin];Q2152617 [nikon 1 v2];Q104154781 [saint lawrence];Q56540279 [planckaert];Q28166941 [le char];Q97119559 [sun temple];Q18339648 [christ on the mount of olives];'},
#  {'dataset': 'wikidata_tables_2023',
#   'table': 'SPIZOSW1',
#   'instruction': 'perform the cell entity annotation (cea) task on this table:',
#   'input': 'Musée Saint-Raymond, 26393;peplos;terracotta|Oinochoe;;clay',
#   'output': '(1,0)=Q55656019 [musée saint-raymond, 26393]|(1,1)=Q1044413 [peplos]|(1,2)=Q60424 [terracotta]|(2,0)=Q87927468 [oinochoe]|(2,2)=Q42302 [clay]',
#   'pool': 'Q3518540 [terracotta];Q60424 [terracotta];Q1044413 [peplos];Q10881223 [yunkai dashan];Q20160670 [template:finnish national road race championships (women)];Q87927468 [oinochoe];Q676576 [ronald reagan washington national airport];Q42302 [clay];Q55656019 [musée saint-raymond, 26393];Q1533644 [stechlin-ruppiner land nature park];Q108058964 [naturdenkmal];Q1558568 [passing];Q1377111 [terracotta];Q2464425 [clay];Q1077969 [freehold township];Q20553894 [eurobasket women 2017];Q4384552 [li li];Q504441 [clark county];Q2206809 [sms cormoran];Q276890 [94 ceti];Q79472 [clay];'},
#  {'dataset': 'wikidata_tables_2023',
#   'table': 'ONX98YWT',
#   'instruction': 'perform the cell entity annotation (cea) task on this table:',
#   'input': '2600 series;|Toei 6000 series;|Keio 8000 series;|M8;|Pendolino;18|S;|R10;400|R12;100|6000 series;|Streamliners;3',
#   'output': '(1,0)=Q4632347 [2600 series]|(2,0)=Q4260383 [toei 6000 series]|(3,0)=Q6383780 [keio 8000 series]|(4,0)=Q6713963 [m8]|(5,0)=Q3757636 [pendolino]|(6,0)=Q4531089 [s]|(7,0)=Q7274365 [r10]|(8,0)=Q7274392 [r12]|(9,0)=Q6108900 [6000 series]|(10,0)=Q18157141 [streamliners]',
#   'pool': "Q210443 [s];Q32845 [misrata district];Q3313974 [1994 milan–san remo];Q4850534 [baldwin county airport];Q1925850 [luton];Q1762809 [newport];Q1075944 [horsham];Q44854521 [catalan regional election 2015 in cervelló];Q114997166 [open journal systems];Q50815971 [village in the rain, with poem on the reverse];Q15339 [shlisselburg];Q97351711 [kreischa];Q16871979 [leather];Q490914 [york county];Q1920919 [mensural notation];Q6108900 [6000 series];Q18157141 [streamliners];Q1479739 [louth];Q13459559 [meeksi];Q4531089 [s];Q4198311 [slate];Q3757636 [pendolino];Q58263021 [1983 vuelta a aragón];Q3855215 [merry christmas, baby av rod stewart];Q1139536 [s];Q115015919 [dr. livesey];Q2782432 [101 park avenue];Q4260383 [toei 6000 series];Q2886439 [toulouse-francazal air base];Q6713963 [m8];Q953307 [la plata];Q97142676 [värmland county administrative board open data];Q286253 [emile male];Q404691 [1931 wimbledon championships – men's singles];Q14897292 [registered heritage place];Q111210960 [paris paris];Q491786 [calvià];Q11699550 [gelsenkirchen zoo train station];Q14946379 [diocese of london];Q14714910 [haddam meadows state park];Q207327 [s];Q102079372 [cain's jawbone];Q90830266 [statuette of an angel];Q540452 [preston leslie];Q2703331 [sovereign];Q61992855 [lages levada a sério];Q56427608 [hoppner];Q55974096 [crocetta railway station];Q4632347 [2600 series];Q7274365 [r10];Q3711533 [6dfgs gj134537.6-122720];Q14927640 [tver];Q31348 [mars, gard];Q58782523 [ship's water];Q61001931 [global telecom];Q6383780 [keio 8000 series];Q11235139 [tōkaidō line (jr west)];Q7274392 [r12];"},
#  {'dataset': 'wikidata_tables_2023',
#   'table': 'TY5S6P04',
#   'instruction': 'perform the cell entity annotation (cea) task on this table:',
#   'input': 'Al Quwaym;1916|Al Qurshah;|Ar Rujum;1976|Mudhaykhirah;2024|Al Kawlah;407|Harbah;1758',
#   'output': '(1,0)=Q12225791 [al quwaym]|(2,0)=Q12225763 [al qurshah]|(3,0)=Q12225434 [ar rujum]|(4,0)=Q12226970 [mudhaykhirah]|(5,0)=Q12225808 [al kawlah]|(6,0)=Q12227036 [harbah]',
#   'pool': "Q12227036 [harbah];Q15271444 [rajshahi district stadium];Q42309166 [lääne-harju rural municipality];Q19248553 [6182];Q12225808 [al kawlah];Q2994502 [shchuka-class submarine];Q12225763 [al qurshah];Q190323 [atlanta];Q541765 [wrzeszcz];Q59853005 [conserved hypothetical protein];Q26103477 [schabloun:willy planckaert];Q12226970 [mudhaykhirah];Q10846596 [berry berry];Q12225791 [al quwaym];Q115811140 [anambra state library board];Q12225434 [ar rujum];Q50815938 [puppies and flowers, with poem on the reverse];Q7306788 [reef];Q60646027 [stechlin];Q115024995 [concert hall];Q678975 [naz];Q774945 [cosmology of j. j. r. tolkien's legendarium];Q13255 [epsilon boötis];Q2272283 [spinnenkop wedderveer];Q1437642 [vélizy-villacoublay];Q13481861 [axiata cup 2013];Q2665609 [tropical storm edouard];"},
#  {'dataset': 'wikidata_tables_2023',
#   'table': 'VXT929LJ',
#   'instruction': 'perform the cell entity annotation (cea) task on this table:',
#   'input': 'Planta do Parque D. Pedro Ii;90|Ypiranga;50|Ypiranga;50|Planta dos Sitios do Moinho;91.5|Planta dos Sitios do Moinho;104|Planta de Terrenos em Santana e Casa Verde;51|Planta de Terrenos em Santana e Casa Verde;62.05|Planta de Terrenos em Santana e Casa Verde;46.4|Planta da Villa de Aricanduva;61.8|Planta da Villa de Aricanduva;61.5',
#   'output': '(1,0)=Q55213000 [planta do parque d. pedro ii]|(2,0)=Q55212614 [ypiranga]|(3,0)=Q55212613 [ypiranga]|(4,0)=Q55212563 [planta dos sitios do moinho]|(5,0)=Q55212561 [planta dos sitios do moinho]|(6,0)=Q55211971 [planta de terrenos em santana e casa verde]|(7,0)=Q55211966 [planta de terrenos em santana e casa verde]|(8,0)=Q55211964 [planta de terrenos em santana e casa verde]|(9,0)=Q55211808 [planta da villa de aricanduva]|(10,0)=Q55211807 [planta da villa de aricanduva]',
#   'pool': 'Q3712655 [doll doll doll];Q55212613 [ypiranga];Q55211807 [planta da villa de aricanduva];Q1375749 [european city];Q822314 [sony pictures entertainment];Q13481298 [1999 welsh badminton championships];Q83964825 [the triceraton homeworld];Q55211966 [planta de terrenos em santana e casa verde];Q11439906 [ōsaka];Q850577 [betz architekten];Q5471713 [fort morris historic site];Q62028773 [união trabalhista por passo fundo];Q49344830 [aucaleuc];Q183021 [nimruz];Q773853 [venice];Q28143 [ballerup];Q55211808 [planta da villa de aricanduva];Q55571896 [birnin kudu];Q4715683 [orange line];Q67622586 [[chm2007] hdc 1092];Q738860 [raymond ceulemans];Q55213000 [planta do parque d. pedro ii];Q29592411 [flowing well fountain];Q10365480 [ruins of tróia];Q55212614 [ypiranga];Q30047542 [liste de survival horror];Q55212561 [planta dos sitios do moinho];Q3366676 [republican party];Q903459 [downtown];Q55212563 [planta dos sitios do moinho];Q39846 [ranch];Q8502 [mountain];Q2535849 [honda rc212v];Q55211964 [planta de terrenos em santana e casa verde];Q66054777 [lauta mining landscape];Q104468094 [chinoiserie];Q103952529 [lubiąż abbey];Q104892776 [latvia];Q55211971 [planta de terrenos em santana e casa verde];Q25167 [bokmål];'},
#  {'dataset': 'wikidata_tables_2023',
#   'table': 'NWZUPFMR',
#   'instruction': 'perform the cell entity annotation (cea) task on this table:',
#   'input': 'copper-67;29;585409.686|copper-71m;29;|copper-73;29;625505.537',
#   'output': '(1,0)=Q18844901 [copper-67]|(2,0)=Q18880194 [copper-71m]|(3,0)=Q18844911 [copper-73]',
#   'pool': "Q18880194 [copper-71m];Q4847311 [clowan:scryssey];Q1372345 [kuopio];Q2986979 [communauté d'agglomération du centre littoral];Q18844901 [copper-67];Q57843118 [preliminary quaternary geologic maps of santa clara valley, santa clara, alameda, and san mateo counties, california: a digital database];Q18844911 [copper-73];Q27877916 [1968 new zealand badminton championships – men's singles];Q1001470 [montenegro];Q494799 [chester county];"},
#  {'dataset': 'wikidata_tables_2023',
#   'table': 'TF13GBS9',
#   'instruction': 'perform the cell entity annotation (cea) task on this table:',
#   'input': 'Namsan Station;2|Myrtle Avenue;4|181st Street;2|Xiaonanmen Station;|Beacon Hill;2|Midtown;|Xinghai Square Station;|Shot Tower;2',
#   'output': '(1,0)=Q705005 [namsan station]|(2,0)=Q2931557 [myrtle avenue]|(3,0)=Q2442219 [181st street]|(4,0)=Q986041 [xiaonanmen station]|(5,0)=Q4875949 [beacon hill]|(6,0)=Q6843070 [midtown]|(7,0)=Q8044546 [xinghai square station]|(8,0)=Q7502403 [shot tower]',
#   'pool': "Q2931557 [myrtle avenue];Q62471080 [royce];Q21683230 [city of southampton];Q12912894 [vidingefjärden];Q20746387 [paolo slongo];Q4875949 [beacon hill];Q4192093 [abun];Q29479966 [judith with the head of holophernes];Q19973853 [de binocle];Q986041 [xiaonanmen station];Q803293 [stuttgart-untertürkheim–kornwestheim railway];Q56651595 [clayton hotel charlemont];Q32856260 [lutsenko];Q18468276 [leiria, pousos, barreira e cortes];Q28169287 [member of parliament];Q7005512 [new bern];Q109409675 [tom and jerry: cowboy up!];Q100901318 [pobucký];Q8255022 [cala nova];Q23818639 [ilberic brandybuck];Q400757 [daviess county];Q63442532 [2008 sri lanka badminton championships – women's doubles];Q71276331 [radionuclide];Q8044546 [xinghai square station];Q7502403 [shot tower];Q60498173 [abira];Q16240082 [james hopwood the younger];Q705005 [namsan station];Q801664 [zittau];Q22128493 [boarding school juliet];Q76633262 [stadtmuseum schwedt/oder];Q20709938 [statutory city];Q2106205 [hong kong];Q2442219 [181st street];Q61038383 [pukaskwa natl park];Q56599248 [iphone xs];Q15700818 [grade i listed building];Q463066 [honda st 1100];Q775595 [gulf islands national park reserve];Q117481254 [san jose civic plaza];Q6843070 [midtown];"},
#  {'dataset': 'wikidata_tables_2023',
#   'table': 'S5XLNQ57',
#   'instruction': 'perform the cell entity annotation (cea) task on this table:',
#   'input': 'Valdosta;Eastern Time Zone;|Stone Mountain;Eastern Time Zone;1839-01-01|Fayetteville;;1823-01-01|Webster County;;1853-12-16|Lookout Mountain;Eastern Time Zone;|Bartow;UTC−05:00;',
#   'output': '(1,0)=Q1010240 [valdosta]|(1,1)=Q941023 [eastern time zone]|(2,0)=Q2073622 [stone mountain]|(2,1)=Q941023 [eastern time zone]|(3,0)=Q782494 [fayetteville]|(4,0)=Q491514 [webster county]|(5,0)=Q2183478 [lookout mountain]|(5,1)=Q941023 [eastern time zone]|(6,0)=Q3261168 [bartow]|(6,1)=Q5390 [utc−05:00]',
#   'pool': "Q3048916 [eurobasket women 2009 squads];Q114486076 [poem sweet poem];Q92076380 [kelčský javorník];Q1010240 [valdosta];Q17642986 [hadrian's wall and vallum in wall mile 66, stanwix bank to stainton];Q495137 [webster county];Q609700 [stone mountain];Q117454380 [spy];Q17213081 [time zone];Q95641465 [eburobrittium (pauly-wissowa)];Q2183478 [lookout mountain];Q588257 [fayetteville];Q785896 [kratié];Q116720815 [valdosta];Q3357767 [ministry of the interior];Q15832296 [amazon web servicesの一覧];Q3261168 [bartow];Q112678953 [valdosta];Q53775 [bartow];Q73860739 [kazi nazrul islam s.s.k.];Q2011796 [stone mountain];Q4847311 [taiss:delete];Q305083 [european city bike];Q6648231 [lithuania];Q782494 [fayetteville];Q5390 [utc−05:00];Q13053618 [armenian concise encyclopedia];Q2165884 [fayetteville];Q1452763 [how can you mend a broken heart];Q491514 [webster county];Q809580 [bartow];Q2073622 [stone mountain];Q485726 [webster county];Q4790608 [english];Q7898751 [upper logging lake snowshoe cabin];Q941023 [eastern time zone];Q13341429 [2013 internationaux de strasbourg – singles];Q7805232 [time zone];Q110980491 [my hero academia];"},
#  {'dataset': 'wikidata_tables_2023',
#   'table': 'QK5VP7SB',
#   'instruction': 'perform the cell entity annotation (cea) task on this table:',
#   'input': 'Canjulao;;1.56|Casate;;4.6|Poblacion III;;0.71|Poblacion III;;0.2365|Maravilla;6;|Buaya;;2.71|Tabalong;16;|Jaclupan;;14.04',
#   'output': '(1,0)=Q26789245 [canjulao]|(2,0)=Q5048060 [casate]|(3,0)=Q28152394 [poblacion iii]|(4,0)=Q7206216 [poblacion iii]|(5,0)=Q28972191 [maravilla]|(6,0)=Q26788637 [buaya]|(7,0)=Q28462746 [tabalong]|(8,0)=Q6118145 [jaclupan]',
#   'pool': "Q18491153 [casate];Q162558 [berlin–görlitz railway];Q803688 [nipe bay];Q61779807 [vidingefjärden coastal water body];Q28152394 [poblacion iii];Q105624136 [soviet navy fleet];Q100270730 [the united kingdom];Q187112 [14th arrondissement of marseille];Q37456553 [antz];Q64759762 [star trek concordance];Q2945230 [centre d'etudes prospectives et d'informations internationales];Q7206216 [poblacion iii];Q59516224 [local government of alimosho];Q15191048 [(77628) 2001 kv46];Q28842167 [poblacion iii];Q26789245 [canjulao];Q5463897 [focus];Q151 [wiktionary];Q17062298 [paradise garden];Q14177 [tabalong];Q16151060 [list of triumph motorcycles];Q56499337 [alpha/beta hydrolase mxdz_rs0209120];Q682015 [armenia];Q488841 [adoration of the magi];Q1135496 [latvian green party];Q28972191 [maravilla];Q108353213 [casate];Q26788637 [buaya];Q58400182 [bartholomew henry allen];Q5048060 [casate];Q6118145 [jaclupan];Q11464598 [shōnen];Q15261136 [øye church];Q28462746 [tabalong];Q5903461 [horizon middle school];Q3132462 [economics];Q924214 [1986 french open];Q18667906 [herb humppila];Q4197830 [jaro, tabalong];Q18490147 [casate];Q1815468 [paris half marathon];Q45036856 [catalan regional election 2015 in la palma d'ebre];Q6410353 [kinai maru];Q59016510 [interpretation of lead isotope abundances];Q69995061 [gj 3512 b];Q6826216 [mexico leututu];Q81021812 [tyc 3139-1857-1];Q207542 [centos];Q664036 [berlin warschauer straße station];Q8085709 [padron:infobox americium];"},
#  {'dataset': 'wikidata_tables_2023',
#   'table': '7E95YXCI',
#   'instruction': 'perform the cell entity annotation (cea) task on this table:',
#   'input': 'Varde River;1090;40|Remstrup Å;;2.5|Mieån;248.3;48|Ansager Å;;20|Höje River;316;45|Uggerby Å;355;55|Havmølle Å;;5|Snoderån;;27|Högvadsån;476;',
#   'output': '(1,0)=Q5767687 [varde river]|(2,0)=Q12333214 [remstrup å]|(3,0)=Q6843979 [mieån]|(4,0)=Q23750323 [ansager å]|(5,0)=Q1501168 [höje river]|(6,0)=Q4504996 [uggerby å]|(7,0)=Q12315850 [havmølle å]|(8,0)=Q7547889 [snoderån]|(9,0)=Q1639460 [högvadsån]',
#   'pool': "Q27085977 [irish chamber];Q12333214 [remstrup å];Q487585 [tashkent];Q1923783 [saint joseph cathedral];Q2258344 [varde];Q34723029 [khlong sam tawan tok];Q116365387 [oil lamp];Q5767687 [varde river];Q30026421 [ivrea];Q6843979 [mieån];Q4504996 [uggerby å];Q1639460 [högvadsån];Q1404649 [fenerbahçe women's basketball];Q107388952 [brösgen];Q18290847 [höje];Q18488843 [zona industriale edilmac];Q12315850 [havmølle å];Q37484654 [strait];Q1530051 [swartland local municipality];Q27350574 [altai mountains];Q43122839 [castell del far d'empordà];Q67146851 [1987 spanish team badminton championships];Q4847311 [malline:pikapoisto];Q2749061 [lpga of japan tour];Q1454776 [singapore];Q18933340 [jahresbericht über die fortschritte der klassischen altertumswissenschaft];Q65114482 [vacheron];Q12763112 [security council of the slovak republic];Q55606775 [catoosa county courthouse];Q17484556 [tapaninkylä dumping ground];Q313819 [anonymous];Q23750323 [ansager å];Q107633612 [höje];Q10613564 [ovanåker civil parish];Q850531 [brno-city district];Q60053 [dongjak station];Q1501168 [höje river];Q863153 [yokohama hakkeijima sea paradise];Q3544632 [walhain-saint-paul];Q7547889 [snoderån];Q71117435 [the preribosome reticulum];Q746157 [copahue];Q2632039 [dashtavan];Q21142 [varde];Q983543 [golden];Q21504696 [arndt];Q3280218 [halo 3: original soundtrack];"},
#  {'dataset': 'wikidata_tables_2023',
#   'table': 'FEFM0QZO',
#   'instruction': 'perform the cell entity annotation (cea) task on this table:',
#   'input': 'Planta da Fazenda Ponte Pensa;95.7|Planta dos Terrenos Na Proximidade da Linha Carris de Ferro S. Paulo - Sto Amaro;63.5',
#   'output': '(1,0)=Q55211251 [planta da fazenda ponte pensa]|(2,0)=Q55211064 [planta dos terrenos na proximidade da linha carris de ferro s. paulo - sto amaro]',
#   'pool': 'Q55211058 [planta dos terrenos na proximidade da linha carris de ferro s. paulo - sto amaro];Q55211064 [planta dos terrenos na proximidade da linha carris de ferro s. paulo - sto amaro];Q51592758 [185 william street];Q44834044 [catalan regional election 2015 in vallès oriental];Q55364824 [planta dos terrenos próximo da linha carris de ferro s. paulo - sto amaro];Q55211251 [planta da fazenda ponte pensa];Q9802263 [fuzhou];'},
#  {'dataset': 'wikidata_tables_2023',
#   'table': 'AUJV2CV3',
#   'instruction': 'perform the cell entity annotation (cea) task on this table:',
#   'input': 'Van der Linden;|Vischer;|Price;|Muirhead family;Russell Muirhead|Amya;|von Zweigbergk;|Leffler;|Ribbentrop;|Rotenhan;|Hebbe;',
#   'output': '(1,0)=Q2669411 [van der linden]|(2,0)=Q2528123 [vischer]|(3,0)=Q12332342 [price]|(4,0)=Q18530428 [muirhead family]|(4,1)=Q18922272 [russell muirhead]|(5,0)=Q481989 [amya]|(6,0)=Q10716848 [von zweigbergk]|(7,0)=Q1812292 [leffler]|(8,0)=Q1559117 [ribbentrop]|(9,0)=Q2168326 [rotenhan]|(10,0)=Q10518809 [hebbe]',
#   'pool': "Q3245449 [list of pokémon introduced in generation v];Q6019705 [india national women's cricket team];Q65921775 [2018 singapore international badminton championships – women's doubles];Q803688 [nipe bay];Q99931036 [marugasaki];Q10518809 [hebbe];Q10716848 [von zweigbergk];Q1989744 [moses];Q1812292 [leffler];Q780913 [austin];Q14935899 [port of port hedland];Q18922272 [russell muirhead];Q774215 [portland];Q18170252 [marmadoc brandybuck];Q3741386 [sz];Q19811668 [2015 tro-bro leon];Q482891 [price];Q63869731 [m. bhanumathi];Q202226 [1969 french open];Q60558215 [modul:location map/data/sweden stockholm municipality];Q6304221 [judson college];Q81028140 [the upgraded arecibo observatory];Q59586172 [neil young live albums discography];Q67189845 [govt degree college totalai];Q18530428 [muirhead family];Q3782198 [2011 hp open – singles];Q54588187 [middle jurassic coptoclavidae];Q12498016 [menden];Q2528123 [vischer];Q2168326 [rotenhan];Q114257999 [1996 fa women's cup final];Q14600700 [kuala lumpur];Q5283863 [dive dive];Q6138045 [james lick telescope];Q2221671 [victorian heritage register];Q18384639 [ag2r la mondiale 2015];Q19509825 [2015 singapore super series];Q4438449 [srebarna];Q27919852 [chester a. arthur];Q3396348 [kuraia];Q59773345 [statue of emmeline pankhurst];Q23797196 [faramir];Q1559117 [ribbentrop];Q87056487 [gemeindemuseum absam];Q806706 [bank of thailand];Q18451778 [musical reference work];Q21402309 [reindorf];Q90702519 [tale of a mermaid];Q119538657 [nigeria jones];Q1191713 [deposition];Q505644 [price];Q39846 [ranch];Q12332342 [price];Q271198 [årstaviken];Q98468155 [s-bahn berlin];Q4956461 [branco mello];Q84551353 [governor of södermanland county];Q2731278 [hartford];Q160151 [price];Q931791 [green lake];Q2669411 [van der linden];Q994991 [bryan coquard];Q1308 [como];Q27864968 [1983 spanish badminton championships – women's doubles];Q2972388 [cil];Q22241356 [sketch of a paw [verso: sketch of a paw and a leg]];Q1446379 [streamwood];Q5430953 [fairy doors of ann arbor, mi];Q172030 [mclaren];Q23309511 [barahir];Q481989 [amya];"},
#  {'dataset': 'wikidata_tables_2023',
#   'table': 'NPEM3U7S',
#   'instruction': 'perform the cell entity annotation (cea) task on this table:',
#   'input': 'Lee County;1065|Richland County;1999',
#   'output': '(1,0)=Q304065 [lee county]|(2,0)=Q505993 [richland county]',
#   'pool': 'Q304065 [lee county];Q501055 [lee county];Q27025 [lee county];Q514008 [lee county];Q126829 [richland county];Q496716 [richland county];Q505993 [richland county];'},
#  {'dataset': 'wikidata_tables_2023',
#   'table': 'UN5G44P4',
#   'instruction': 'perform the cell entity annotation (cea) task on this table:',
#   'input': 'sheep pen;architectural heritage monument|Stall;architectural heritage monument in Bavaria|Stall;architectural heritage monument in Bavaria|Stall;architectural heritage monument in Bavaria|Stall;architectural heritage monument in Bavaria|Stall;architectural heritage monument in Bavaria|Stall;architectural heritage monument in Bavaria|Stall;architectural heritage monument in Bavaria|Stall;architectural heritage monument in Bavaria|Stall;architectural heritage monument in Bavaria',
#   'output': '(1,0)=Q27732613 [sheep pen]|(1,1)=Q811165 [architectural heritage monument]|(2,0)=Q98496900 [stall]|(2,1)=Q17297633 [architectural heritage monument in bavaria]|(3,0)=Q98621560 [stall]|(3,1)=Q17297633 [architectural heritage monument in bavaria]|(4,0)=Q98622449 [stall]|(4,1)=Q17297633 [architectural heritage monument in bavaria]|(5,0)=Q98627008 [stall]|(5,1)=Q17297633 [architectural heritage monument in bavaria]|(6,0)=Q98628497 [stall]|(6,1)=Q17297633 [architectural heritage monument in bavaria]|(7,0)=Q41324681 [stall]|(7,1)=Q17297633 [architectural heritage monument in bavaria]|(8,0)=Q98696222 [stall]|(8,1)=Q17297633 [architectural heritage monument in bavaria]|(9,0)=Q98696312 [stall]|(9,1)=Q17297633 [architectural heritage monument in bavaria]|(10,0)=Q98632714 [stall]|(10,1)=Q17297633 [architectural heritage monument in bavaria]',
#   'pool': 'Q49340369 [sheep pen basin];Q1608140 [list of architectural heritage monuments in bavaria];Q811165 [architectural heritage monument];Q98100466 [former architectural heritage monument in bavaria];Q17379996 [sheep pen sandstone];Q98622449 [stall];Q98496900 [stall];Q98621560 [stall];Q752034 [stall];Q98628497 [stall];Q98632714 [stall];Q4787025 [architectural heritage];Q41324681 [stall];Q278359 [stall];Q98696222 [stall];Q98627008 [stall];Q1207909 [stall];Q98696312 [stall];Q27732613 [sheep pen];Q17297633 [architectural heritage monument in bavaria];Q3369996 [architectural heritage];'},
#  {'dataset': 'wikidata_tables_2023',
#   'table': 'BQC7DZZR',
#   'instruction': 'perform the cell entity annotation (cea) task on this table:',
#   'input': 'Brookville Township;67.09;192|Miller Township;26.37;173|Mill Township;23.19;259|Greenville Township;33.5;250|Princeton Township;62.53;211',
#   'output': '(1,0)=Q4975221 [brookville township]|(2,0)=Q7996163 [miller township]|(3,0)=Q6858435 [mill township]|(4,0)=Q5604744 [greenville township]|(5,0)=Q5858248 [princeton township]',
#   'pool': 'Q5858248 [princeton township];Q1074743 [govan];Q4975221 [brookville township];Q78250951 [v* v1778 ori];Q50818690 [three red guards with chairman mao banner];Q1504893 [kreisverkehr schwäbisch hall];Q7393610 [ss empire clough];Q6859275 [miller township];Q5947216 [hurricane bob];Q7996163 [miller township];Q6859266 [miller township];Q5640345 [greenville township];Q56649397 [adamsdown];Q6858435 [mill township];Q5604743 [greenville township];Q7999086 [miller township];Q5604744 [greenville township];Q104712921 [charvát josef];Q58263024 [1984 vuelta a aragón];'},
#  {'dataset': 'wikidata_tables_2023',
#   'table': 'B72Q14SI',
#   'instruction': 'perform the cell entity annotation (cea) task on this table:',
#   'input': 'Stall Raitenhaslach 7 in Burghausen;architectural heritage monument in Bavaria|Stall Maisenberg 31 in Engelsberg;architectural heritage monument in Bavaria|Stall Maisenberg 31 in Engelsberg;architectural heritage monument in Bavaria|Stall St.-Leonhard-Straße 24 in Rothenburg ob der Tauber;architectural heritage monument in Bavaria|Stall Hauptstraße 20 in Reuth bei Erbendorf;architectural heritage monument in Bavaria',
#   'output': '(1,0)=Q98741418 [stall raitenhaslach 7 in burghausen]|(1,1)=Q17297633 [architectural heritage monument in bavaria]|(2,0)=Q98750814 [stall maisenberg 31 in engelsberg]|(2,1)=Q17297633 [architectural heritage monument in bavaria]|(3,0)=Q98750817 [stall maisenberg 31 in engelsberg]|(3,1)=Q17297633 [architectural heritage monument in bavaria]|(4,0)=Q98632441 [stall st.-leonhard-straße 24 in rothenburg ob der tauber]|(4,1)=Q17297633 [architectural heritage monument in bavaria]|(5,0)=Q98682916 [stall hauptstraße 20 in reuth bei erbendorf]|(5,1)=Q17297633 [architectural heritage monument in bavaria]',
#   'pool': 'Q1608140 [list of architectural heritage monuments in bavaria];Q98100466 [former architectural heritage monument in bavaria];Q117453620 [mercury];Q30918972 [trat];Q98750814 [stall maisenberg 31 in engelsberg];Q55092326 [road bridge];Q98741418 [stall raitenhaslach 7 in burghausen];Q190095 [gray];Q27525351 [wikidata property related to music];Q59853005 [conserved hypothetical protein];Q21384726 [tilia cordata cordata];Q17468627 [tha sai];Q98632441 [stall st.-leonhard-straße 24 in rothenburg ob der tauber];Q50815961 [cranes, with poem on the reverse];Q4864473 [barry mason];Q19875371 [manoora];Q98750817 [stall maisenberg 31 in engelsberg];Q17297633 [architectural heritage monument in bavaria];Q58354132 [sms power];Q1994608 [avondale, louisiana];Q98682916 [stall hauptstraße 20 in reuth bei erbendorf];Q16232771 [m. mexico];Q7531857 [sithney common];'},
#  {'dataset': 'wikidata_tables_2023',
#   'table': '491H44F5',
#   'instruction': 'perform the cell entity annotation (cea) task on this table:',
#   'input': 'Etimesgut railway station;2|Samnangjin Station;3|El Papiol station;|Avenches railway station;2|Gorinchem railway station;|Stein am Rhein railway station;2|Schnega;',
#   'output': '(1,0)=Q55611107 [etimesgut railway station]|(2,0)=Q477097 [samnangjin station]|(3,0)=Q387929 [el papiol station]|(4,0)=Q31451373 [avenches railway station]|(5,0)=Q125098 [gorinchem railway station]|(6,0)=Q13416896 [stein am rhein railway station]|(7,0)=Q801415 [schnega]',
#   'pool': "Q10587563 [molde];Q2356548 [d810];Q4201310 [medan johor, medan];Q1069978 [beaulieu];Q1183094 [shrewsbury];Q31451373 [avenches railway station];Q13416896 [stein am rhein railway station];Q575782 [nasdaq];Q65922527 [1997 singapore open badminton championships – women's doubles];Q110709550 [yad vashem];Q114158749 [1984 hurricane season];Q704864 [tamworth];Q81949 [barcelona];Q3815484 [kings and queens];Q262431 [the hallé];Q55611107 [etimesgut railway station];Q28127371 [öbb nightjet];Q211511 [russia-1];Q112997581 [cerebral blood circulation];Q5524331 [garth];Q125098 [gorinchem railway station];Q5754276 [higgins armory museum];Q387929 [el papiol station];Q15007947 [template:localities in alvesta municipality];Q3840598 [lumia];Q477097 [samnangjin station];Q111266417 [1992 spanish junior badminton championships u19];Q801415 [schnega];Q93840923 [cottbus–żary railway line];Q4384552 [li li];Q40362 [sahrawi arab democratic republic];Q7673980 [tacoma];Q22352344 [lac brécourt];Q5926174 [japanese];Q52288232 [thomas jones];Q179948 [évora];Q64293261 [the united states territory of hawaii];"},
#  {'dataset': 'wikidata_tables_2023',
#   'table': 'UA25BKIA',
#   'instruction': 'perform the cell entity annotation (cea) task on this table:',
#   'input': "figure skating at the 2020 Winter Youth Olympics – pair skating;8|figure skating at the 2020 Winter Youth Olympics – ice dancing;12|figure skating at the 2020 Winter Youth Olympics – girls' singles;16|alpine skiing at the 2020 Winter Youth Olympics – boys' super-G;61|figure skating at the 2020 Winter Youth Olympics – boys' singles;15|modern pentathlon at the 2018 Summer Youth Olympics – mixed relay;46|modern pentathlon at the 2018 Summer Youth Olympics – girls' individual;24",
#   'output': "(1,0)=Q81653788 [figure skating at the 2020 winter youth olympics – pair skating]|(2,0)=Q81653715 [figure skating at the 2020 winter youth olympics – ice dancing]|(3,0)=Q81653627 [figure skating at the 2020 winter youth olympics – girls' singles]|(4,0)=Q81644416 [alpine skiing at the 2020 winter youth olympics – boys' super-g]|(5,0)=Q81546427 [figure skating at the 2020 winter youth olympics – boys' singles]|(6,0)=Q60785861 [modern pentathlon at the 2018 summer youth olympics – mixed relay]|(7,0)=Q60785825 [modern pentathlon at the 2018 summer youth olympics – girls' individual]",
#   'pool': "Q3897934 [figure skating at the 2012 winter youth olympics – ice dancing];Q12223974 [internationaux de strasbourg 2013];Q84305407 [figure skating at the 2020 winter youth olympics – pair skating free skating];Q3897933 [figure skating at the 2012 winter youth olympics – boys' singles];Q189936 [game];Q81653627 [figure skating at the 2020 winter youth olympics – girls' singles];Q63871716 [journal of public affairs education];Q84305411 [figure skating at the 2020 winter youth olympics – ice dancing rhythm dance];Q81644416 [alpine skiing at the 2020 winter youth olympics – boys' super-g];Q47532012 [comité pour l'histoire de la poste];Q3897931 [figure skating at the 2012 winter youth olympics – pair skating];Q60785825 [modern pentathlon at the 2018 summer youth olympics – girls' individual];Q81653788 [figure skating at the 2020 winter youth olympics – pair skating];Q60785861 [modern pentathlon at the 2018 summer youth olympics – mixed relay];Q684870 [otley];Q81546427 [figure skating at the 2020 winter youth olympics – boys' singles];Q81653715 [figure skating at the 2020 winter youth olympics – ice dancing];Q1614763 [2010 spanish international badminton championships];Q65558243 [dj tennis];Q3646205 [eteriani];Q3897932 [figure skating at the 2012 winter youth olympics – girls' singles];Q27878503 [1957 new zealand badminton championships – women's singles];"},
#  {'dataset': 'wikidata_tables_2023',
#   'table': 'K4A0E0QL',
#   'instruction': 'perform the cell entity annotation (cea) task on this table:',
#   'input': 'La Belle;48;39;22|Aconit;100;44;15',
#   'output': '(1,0)=Q47544387 [la belle]|(2,0)=Q47537623 [aconit]',
#   'pool': 'Q13360453 [template:campaignbox mexican–american war];Q47537623 [aconit];Q27118503 [southwest cay];Q47544387 [la belle];Q2748345 [aconit];Q507541 [band on the run];Q5502113 [aconit];'},
#  {'dataset': 'wikidata_tables_2023',
#   'table': 'B05RYX3W',
#   'instruction': 'perform the cell entity annotation (cea) task on this table:',
#   'input': 'Berducedo;899|Soto de Luiña;16|Nembro;58|Cerredo;669|Bergame;669|Augüera;316|Gobiendes;77|La Rebollá;345|Marentes;295',
#   'output': '(1,0)=Q818870 [berducedo]|(2,0)=Q5195544 [soto de luiña]|(3,0)=Q6991056 [nembro]|(4,0)=Q5064813 [cerredo]|(5,0)=Q4891430 [bergame]|(6,0)=Q399656 [agüera]|(7,0)=Q5575504 [gobiendes]|(8,0)=Q20618902 [la rebollá]|(9,0)=Q611773 [marentes]',
#   'pool': "Q4922906 [kaokor galaxy];Q1169393 [2010 spanish badminton championships];Q399656 [agüera];Q141777 [maniwaki];Q104011090 [sacra di san michele];Q16743864 [faust];Q78247232 [v* v2281 ori];Q20618902 [la rebollá];Q7098843 [wikiproject anime and manga];Q4891430 [bergame];Q21514353 [allowed units constraint];Q110860274 [burgerbelangen overbetuwe];Q15752280 [yad vashem studies];Q6991056 [nembro];Q5195544 [soto de luiña];Q5064813 [cerredo];Q95519426 [free software tools];Q48878 [pierce county];Q5575504 [gobiendes];Q339 [pluton];Q300410 [a foggy day];Q48784243 [mac's imp];Q151922 [paul];Q108280869 [united kingdom];Q3800353 [1925 french championships – women's singles];Q4847311 [šabluons:delete];Q611773 [marentes];Q736731 [the three caballeros];Q30509843 [glennon];Q116032163 [haus paradiesgärtlein];Q818870 [berducedo];Q65102900 [2003 china open badminton championships – men's doubles];Q2490500 [2013 asb classic – doubles];Q30625628 [duddepudi, west godavari district];"},
#  {'dataset': 'wikidata_tables_2023',
#   'table': 'UJOB91TJ',
#   'instruction': 'perform the cell entity annotation (cea) task on this table:',
#   'input': 'copper-66;29;576277.152|copper-74;29;630595.588',
#   'output': '(1,0)=Q18844900 [copper-66]|(2,0)=Q18844912 [copper-74]',
#   'pool': 'Q18844900 [copper-66];Q4847311 [clowan:scryssey];Q18844912 [copper-74];'},
#  {'dataset': 'wikidata_tables_2023',
#   'table': 'P0V3VJRK',
#   'instruction': 'perform the cell entity annotation (cea) task on this table:',
#   'input': 'Progressive Corporation;vehicle insurance;Mayfield|Pasargad  Insurance;life insurance;Poldasht|SIC Insurance Company;insurance industry;Osu|Erie Insurance Group;insurance;Erie|Assuranceforeningen Gard;insurance;Arendal',
#   'output': '(1,0)=Q7248721 [progressive corporation]|(1,1)=Q1068361 [vehicle insurance]|(1,2)=Q2604968 [mayfield village, ohio]|(2,0)=Q5930269 [pasargad  insurance]|(2,1)=Q626608 [life insurance]|(2,2)=Q2556849 [poldasht]|(3,0)=Q7390288 [sic insurance company]|(3,1)=Q2518196 [insurance industry]|(3,2)=Q1752686 [osu]|(4,0)=Q5388314 [erie insurance group]|(4,1)=Q43183 [insurance]|(4,2)=Q234061 [erie]|(5,0)=Q4810400 [assuranceforeningen gard]|(5,1)=Q43183 [insurance]|(5,2)=Q57919 [arendal]',
#   'pool': "Q1012364 [mayfield];Q2699921 [arendal];Q5348296 [egypt];Q18426618 [cerro, l'aquila];Q28753159 [municipal elections 2012 in kaavi in finland];Q50818329 [prosperous flowers around the yinchu lake];Q47512391 [insurance];Q12061751 [henry hoppner meyer];Q5388314 [erie insurance group];Q79263119 [architecture of maybeck];Q14828790 [alpha quadrant];Q57919 [arendal];Q33603417 [chapter 6: insurance industry];Q638883 [tom and jerry: the magic ring];Q117718312 [multi-purpose hall hönebach];Q56229420 [journals that converted from toll access to open access (open access directory)];Q234061 [erie];Q112130247 [insurance];Q57032510 [organia];Q6411006 [king's manor];Q48606704 [central nervous system];Q2604968 [mayfield village, ohio];Q16126459 [misr insurance company];Q1073359 [1991 china open badminton championships];Q19946010 [surry county courthouse];Q2604968 [mayfield];Q18429932 [melilla];Q31809300 [maguran reef];Q215273 [red hat enterprise linux];Q3461625 [mayfield];Q17050915 [insurance industry in china];Q11761948 [lithuania];Q613198 [gioia metro station];Q19943292 [gelora bung karno];Q2556849 [poldasht];Q7390288 [sic insurance company];Q2143354 [insurance company];Q2955013 [1965 french figure skating championships];Q5492 [erie];Q43183 [insurance];Q7248721 [progressive corporation];Q4810400 [assuranceforeningen gard];Q65043724 [root insurance company];Q258571 [erie];Q1068361 [vehicle insurance];Q5930269 [pasargad  insurance];Q626608 [life insurance];Q50502874 [red cabbage];Q2518196 [insurance industry];Q51912507 [obersendling];Q1752686 [osu];Q1012345 [erie];Q3377814 [arendal];"},
#  {'dataset': 'wikidata_tables_2023',
#   'table': 'T6T2RBKQ',
#   'instruction': 'perform the cell entity annotation (cea) task on this table:',
#   'input': 'Palma Soriano;150|Placetas;205|Majagua;110|Minas de Matahambre;115|Campechuela;10|Minas;70|La Palma;50|Mantua;30|Rodas;25|Abreus;60',
#   'output': '(1,0)=Q742835 [palma soriano]|(2,0)=Q861701 [placetas]|(3,0)=Q1886040 [majagua]|(4,0)=Q2204246 [minas de matahambre]|(5,0)=Q1332135 [campechuela]|(6,0)=Q643025 [minas]|(7,0)=Q2234325 [la palma]|(8,0)=Q2213002 [mantua]|(9,0)=Q5004 [rodas]|(10,0)=Q331384 [abreus]',
#   'pool': "Q16204 [mantua];Q791056 [avinurme rural municipality];Q1578797 [la palma];Q485150 [romanian];Q1578953 [ospina];Q861701 [placetas];Q65922633 [1990 singapore open badminton championships – mixed doubles];Q383592 [cycles peugeot];Q234200 [santiago de cuba province];Q47489031 [inn];Q103973622 [western sahara];Q117454349 [january];Q28169287 [member of parliament];Q41210563 [kriegerdenkmal perlach];Q22698 [park];Q2131270 [mantua];Q79745734 [2006 bulgaria open badminton championships – men's doubles];Q643025 [minas];Q2234325 [la palma];Q799396 [2009 world junior badminton championships];Q331384 [abreus];Q25477702 [national institute of immovable cultural heritage];Q6247 [mantua];Q742835 [palma soriano];Q5004 [rodas];Q12015578 [urban municipality];Q4304851 [motaĺski sieĺsaviet];Q1332135 [campechuela];Q1886040 [majagua];Q595175 [la palma];Q28442826 [the beauty];Q2204246 [minas de matahambre];Q5748933 [carbajal de valderaduey];Q2213002 [mantua];Q201689 [la palma];Q7895818 [university of mississippi medical center];Q3089803 [tropical storm harvey];Q840852 [chulalongkorn university stadium];Q23653 [anthology series];Q15827202 [national register of historic places listings in adams county, wisconsin];"},
#  {'dataset': 'wikidata_tables_2023',
#   'table': 'G96COWDQ',
#   'instruction': 'perform the cell entity annotation (cea) task on this table:',
#   'input': 'Rabbi Levi;2500|Horrocks;2980|Miller;3550|Hayn;4480|Vieta;4500|Werner;4200|Hevelius;1930|Gutenberg;2300',
#   'output': '(1,0)=Q1634499 [rabbi levi]|(2,0)=Q1628896 [horrocks]|(3,0)=Q1600297 [miller]|(4,0)=Q1591969 [hayn]|(5,0)=Q1572228 [vieta]|(6,0)=Q1571793 [werner]|(7,0)=Q1565861 [hevelius]|(8,0)=Q1557168 [gutenberg]',
#   'pool': "Q65922509 [1969 singapore open badminton championships – women's doubles];Q279601 [werner];Q1565861 [hevelius];Q22384585 [sainte-anne-des-monts];Q76812448 [msx lmc 1284];Q502261 [silence];Q694116 [miller];Q25844222 [šablon:william cameron menzies];Q103973622 [western sahara];Q1557168 [gutenberg];Q676823 [werner];Q953852 [miller];Q1442181 [thổ chu islands];Q1634499 [rabbi levi];Q1002598 [zhengzhou metro];Q3882012 [olympiacos women's volleyball];Q17515547 [wwe network];Q1628896 [horrocks];Q2474066 [miller];Q1600297 [miller];Q10719642 [werner och werner];Q1571793 [werner];Q52988270 [commezzadura - mestriago];Q67146853 [1989 spanish team badminton championships];Q10333277 [city walls of porto];Q1572228 [vieta];Q7538854 [slate];Q27207826 [2016 uci road world championships – women's road race];Q64298379 [tantalum];Q1751326 [new rose];Q1591969 [hayn];Q27020543 [2016 welsh badminton championships];"},
#  {'dataset': 'wikidata_tables_2023',
#   'table': '8SF4PGAN',
#   'instruction': 'perform the cell entity annotation (cea) task on this table:',
#   'input': 'Hurricane Elida;921|Hurricane Mitch;905',
#   'output': '(1,0)=Q498308 [hurricane elida]|(2,0)=Q390115 [hurricane mitch]',
#   'pool': 'Q64495631 [hurricane elida];Q6321089 [hurricane elida];Q17109579 [meteorological history of hurricane mitch];Q498308 [hurricane elida];Q390115 [hurricane mitch];Q96477485 [hurricane mitch];'},
#  {'dataset': 'wikidata_tables_2023',
#   'table': '6KJ5X8V6',
#   'instruction': 'perform the cell entity annotation (cea) task on this table:',
#   'input': 'Chinese Civil War;Chinese Communist Party|Russian Civil War;Australia',
#   'output': '(1,0)=Q179975 [chinese civil war]|(1,1)=Q17427 [communist party of china]|(2,0)=Q79911 [russian civil war]|(2,1)=Q408 [australia]',
#   'pool': 'Q179975 [chinese civil war];Q3960 [australia];Q21716800 [abraham and three angels];Q20016417 [australia navarro];Q118900212 [chinese civil war];Q11106914 [template:eastern front of russian civil war];Q79911 [russian civil war];Q408 [australia];Q6856448 [سانچہ:campaignbox russian civil war];Q6855446 [الگو:campaignbox chinese civil war];Q275180 [australia];Q60826781 [plaza de la revolución];Q17427 [communist party of china];Q49957 [large magellanic cloud];'},
#  {'dataset': 'wikidata_tables_2023',
#   'table': 'YZ9MV0AZ',
#   'instruction': 'perform the cell entity annotation (cea) task on this table:',
#   'input': 'Allt Lwyd;654;27.7|Hausberg;391.7;26|Bryn-teg;136;37|Carreg Cennen;266;37',
#   'output': '(1,0)=Q4733303 [allt lwyd]|(2,0)=Q1591011 [hausberg]|(3,0)=Q106711562 [bryn-teg]|(4,0)=Q106711471 [carreg cennen]',
#   'pool': 'Q21350353 [wiltshirocossus aries aries];Q48213582 [ellen];Q1591011 [hausberg];Q193321 [java virtual machine];Q3646426 [2008 budapest grand prix – doubles];Q7884146 [unearthly];Q4733303 [allt lwyd];Q3278502 [town hall of paris 7th arrondissement];Q247032 [warner communications inc.];Q106711562 [bryn-teg];Q106711471 [carreg cennen];Q2436788 [floreni];Q3694465 [pol-e khomri];Q37750505 [ansitz];Q15735659 [wat arun];Q202129 [judith];'},
#  {'dataset': 'wikidata_tables_2023',
#   'table': 'GJDSU7RN',
#   'instruction': 'perform the cell entity annotation (cea) task on this table:',
#   'input': 'Thailand Route 232;|Thailand Route 34;|Ontario Highway 566;Matachewan|Changlun–Kuala Perlis Highway;|Provincial Highway 14D;Nantou City|County Highway 205;Magong',
#   'output': '(1,0)=Q16305997 [thailand route 232]|(2,0)=Q1679840 [thailand route 34]|(3,0)=Q104880674 [ontario highway 566]|(3,1)=Q6785928 [matachewan]|(4,0)=Q5072082 [changlun–kuala perlis highway]|(5,0)=Q107285731 [provincial highway 14d]|(5,1)=Q715171 [nantou city]|(6,0)=Q17032660 [county highway 205]|(6,1)=Q701428 [magong]',
#   'pool': 'Q3782190 [2009 hp open – doubles];Q17032660 [county highway 205];Q13913 [badia del vallès];Q5072082 [changlun–kuala perlis highway];Q6785928 [matachewan];Q3143983 [lekkerkerk];Q762619 [nieuw amsterdam, suriname];Q11634 [art of sculpture];Q487610 [cortland county];Q52839107 [padre ernesto balducci];Q628118 [rüdesheim am rhein];Q693956 [hamburg s-bahn];Q109827448 [oudtshoorn local municipality elections];Q1455386 [french open 1993];Q6616990 [шаблон:тур wta 1988];Q516086 [1927 french championships];Q87878188 [v592 herculis];Q1371037 [institute of technology];Q104880674 [ontario highway 566];Q37028551 [herden];Q107285731 [provincial highway 14d];Q25129 [langeoog];Q6937716 [polis polis potatismos];Q1188361 [warner home video];Q24022125 [agullana];Q18429932 [melilla];Q7611170 [cn];Q46002125 [market hall];Q3096600 [győr];Q905721 [hidaka];Q7097010 [operation duryodhana];Q1143622 [cumae];Q1679840 [thailand route 34];Q16515528 [karancs];Q1570473 [kiel];Q2220214 [lincoln township];Q701428 [magong];Q642741 [division no. 23, manitoba];Q28469404 [cadillac township];Q61650124 [quai des célestins];Q491170 [rock county];Q16305997 [thailand route 232];Q715171 [nantou city];Q6867688 [ministry of the interior];Q62028775 [trabalho por uma paulista sustentável];'},
#  {'dataset': 'wikidata_tables_2023',
#   'table': 'SMD4H2MW',
#   'instruction': 'perform the cell entity annotation (cea) task on this table:',
#   'input': 'Pauline Johnson;poetry;Canada;1913-03-07|Tacitus;history;Ancient Rome;0120-01-01',
#   'output': '(1,0)=Q2716914 [pauline johnson]|(1,1)=Q482 [poetry]|(1,2)=Q16 [canada]|(2,0)=Q2161 [tacitus]|(2,1)=Q309 [history]|(2,2)=Q1747689 [ancient rome]',
#   'pool': 'Q2161 [tacitus];Q309 [history];Q1031985 [canada lee];Q19560748 [h. poetry];Q1387079 [glenncunningham history];Q115494716 [ancient rome];Q93343 [shelly poetry];Q111974907 [e. poetry];Q152082 [r. canada];Q16932211 [south georgia and south sandwich islands gazette];Q2716914 [pauline johnson];Q159592 [jothan nepior history];Q3094657 [ancient rome];Q76771 [richard abegg history];Q55081382 [jordin canada];Q3448505 [rue jean-poulmarch];Q98716409 [ancient rome];Q1747689 [ancient rome];Q22070928 [rio das ostras];Q741573 [french open 2009];Q482 [poetry];Q16 [canada];Q1569489 [sun prairie];Q3112564 [government of new south wales];'},
#  {'dataset': 'wikidata_tables_2023',
#   'table': 'QN3CDMMP',
#   'instruction': 'perform the cell entity annotation (cea) task on this table:',
#   'input': 'Stall Krumbach 23; Krumbach 24 in Halsbach;architectural heritage monument in Bavaria|Stall Lämmersreut 8 in Waldkirchen;architectural heritage monument in Bavaria|Stall Lohen 4 in Maitenbeth;architectural heritage monument in Bavaria|Schweinestall Rottenegger Straße 1 in Wolnzach;architectural heritage monument in Bavaria|Schweinestall Weingartsgreuth 58 in Wachenroth;architectural heritage monument in Bavaria|Schweinestall Krottenbacher Straße 86 in Nürnberg;architectural heritage monument in Bavaria|Stall Kronest 1 in Trostberg;architectural heritage monument in Bavaria|Stall Conrad-Celtis-Straße 14 in Wipfeld;architectural heritage monument in Bavaria',
#   'output': '(1,0)=Q98741600 [stall krumbach 23; krumbach 24 in halsbach]|(1,1)=Q17297633 [architectural heritage monument in bavaria]|(2,0)=Q98698821 [stall lämmersreut 8 in waldkirchen]|(2,1)=Q17297633 [architectural heritage monument in bavaria]|(3,0)=Q98745435 [stall lohen 4 in maitenbeth]|(3,1)=Q17297633 [architectural heritage monument in bavaria]|(4,0)=Q98748573 [schweinestall rottenegger straße 1 in wolnzach]|(4,1)=Q17297633 [architectural heritage monument in bavaria]|(5,0)=Q98634755 [schweinestall weingartsgreuth 58 in wachenroth]|(5,1)=Q17297633 [architectural heritage monument in bavaria]|(6,0)=Q98629724 [schweinestall krottenbacher straße 86 in nürnberg]|(6,1)=Q17297633 [architectural heritage monument in bavaria]|(7,0)=Q98752001 [stall kronest 1 in trostberg]|(7,1)=Q17297633 [architectural heritage monument in bavaria]|(8,0)=Q98497085 [stall conrad-celtis-straße 14 in wipfeld]|(8,1)=Q17297633 [architectural heritage monument in bavaria]',
#   'pool': 'Q1608140 [list of architectural heritage monuments in bavaria];Q98100466 [former architectural heritage monument in bavaria];Q1378654 [grip stave church];Q98748573 [schweinestall rottenegger straße 1 in wolnzach];Q502356 [meigs county];Q1415628 [march];Q5599084 [great ealing school];Q7649496 [sussex west];Q22074942 [wolf 1061 d];Q29002343 [mondelēz international (singapore)];Q98634755 [schweinestall weingartsgreuth 58 in wachenroth];Q713385 [daliao];Q98745435 [stall lohen 4 in maitenbeth];Q98698821 [stall lämmersreut 8 in waldkirchen];Q98741600 [stall krumbach 23; krumbach 24 in halsbach];Q1062205 [changzhou];Q1022193 [březová];Q465469 [american league];Q98629724 [schweinestall krottenbacher straße 86 in nürnberg];Q63148962 [mutual dell organization camp];Q17072077 [north korea tech];Q1334011 [tōsandō];Q104640389 [place du carrousel];Q188782 [malta];Q113413517 [avenue ledru-rollin];Q17297633 [architectural heritage monument in bavaria];Q5697147 [old cathedral of segovia];Q30242014 [2017 aegon open nottingham (women)];Q22726827 [format:john m. stahl];Q115792531 [tufo-pardus prostějov 2019];Q98497085 [stall conrad-celtis-straße 14 in wipfeld];Q114678860 [wat wat wat];Q98752001 [stall kronest 1 in trostberg];Q4928445 [blossom time];Q661809 [die doppelte nummer];'},
#  {'dataset': 'wikidata_tables_2023',
#   'table': '54ZDXWQJ',
#   'instruction': 'perform the cell entity annotation (cea) task on this table:',
#   'input': 'ESO 36-3;4721;-75.4302846156636;124.9825538407281|ESO 36-2;14188;-73.7670387126404;124.6694708807607|ESO 58-6;11207;-70.7406917;98.2069708|ESO 108-1;17298;-64.434278;325.65725|ESO 107-26;17416;-64.312056;320.911417|ESO 569-2;3124;-22.1521361;161.2503208|ESO 568-22;2203;-22.10556;160.52708|ESO 488-29;12149;-25.55972;87.18708|ESO 108-8;15850;-62.655333;329.778875|ESO 145-23;26726;-61.9021629241862;328.3583124796155',
#   'output': '(1,0)=Q88088546 [eso 36-3]|(2,0)=Q88088286 [eso 36-2]|(3,0)=Q88083328 [eso 58-6]|(4,0)=Q88083065 [eso 108-1]|(5,0)=Q88082839 [eso 107-26]|(6,0)=Q88069514 [eso 569-2]|(7,0)=Q88069302 [eso 568-22]|(8,0)=Q88059555 [eso 488-29]|(9,0)=Q88057526 [eso 108-8]|(10,0)=Q88057470 [eso 145-23]',
# ...
#  {'dataset': 'wikidata_tables_2023',
#   'table': 'R7HQ3B55',
#   'instruction': 'perform the cell entity annotation (cea) task on this table:',
#   'input': "Flushed Away;84;178120010|Ted Sieger's Molly Monster;72;|Coconut, the Little Dragon;83;|The Aristocats;78;191000000|Ocean Waves;72;|Superman: Red Son;84;|Ice Age: Dawn of the Dinosaurs;94;886686817|Kung Fu Panda;92;631746197|Dobrynya Nikitich and Zmey Gorynych;62;100529754",
#   'output': "(1,0)=Q752301 [flushed away]|(2,0)=Q26262105 [ted sieger's molly monster]|(3,0)=Q20184371 [coconut, the little dragon]|(4,0)=Q184701 [the aristocats]|(5,0)=Q740339 [ocean waves]|(6,0)=Q78914620 [superman: red son]|(7,0)=Q179503 [ice age: dawn of the dinosaurs]|(8,0)=Q129193 [kung fu panda]|(9,0)=Q2378287 [dobrynya nikitich and zmey gorynych]",
#   'pool': "Q184701 [the aristocats];Q107623092 [socialism];Q2378287 [dobrynya nikitich and zmey gorynych];Q27087568 [burnside monument, brompton cemetery];Q7257449 [public libraries];Q15414124 [cannondale 2014];Q2050623 [paper];Q5597741 [b. coal];Q179503 [ice age: dawn of the dinosaurs];Q3395875 [psychoanalytic literary criticism];Q4784257 [flughafen bartolomeu de gusmão];Q129193 [kung fu panda];Q25212384 [flushed];Q2381874 [dinan];Q156257 [allegany county];Q752301 [flushed away];Q105560708 [richard tom-1];Q89181520 [surveying what's flushed away];Q86500098 [royal house order of hohenzollern];Q502074 [heliport];Q263518 [louisiana red];Q24207221 [von der bellen];Q163966 [mitte];Q940748 [tenterfield shire];Q17778924 [grunnkretser i nore og uvdal kommune];Q31521182 [buyabod port 2];Q1013534 [burg püttlingen];Q30047542 [liste de survival horror];Q61749428 [ein engel für alle fälle];Q65922631 [1971 singapore open badminton championships – mixed doubles];Q3353865 [1998 toray pan pacific open];Q148475 [camille corot];Q50818744 [set of eight papercuts depicting the attitude of yan'an workers and their envelope];Q68246687 [yz canis minoris];Q55012787 [metcalfe county kentucky courthouse];Q29903068 [royal academy of pharmacy building];Q3241792 [panthera leo leo];Q20184371 [coconut, the little dragon];Q78914620 [superman: red son];Q740339 [ocean waves];Q2781236 [69th regiment armory];Q26262105 [ted sieger's molly monster];Q41966115 [cinema xxx, great windmill street];Q30623998 [kothagudem, west godavari district];Q458174 [laurent pichon];Q99232005 [a woman of the world];Q1648096 [black lantern corps];"},
#  {'dataset': 'wikidata_tables_2023',
#   'table': 'PHMCQD1C',
#   'instruction': 'perform the cell entity annotation (cea) task on this table:',
#   'input': 'Nebel;11.96;6|Loddin;6.12;21|Bognor Regis;4.41;|Eastbourne;44.16;22|Golden Sands;;24|Sinemorets;;46|Cleethorpes;9.4;|Katwijk aan Zee;1.8;|Emona;;108',
#   'output': '(1,0)=Q21042 [nebel]|(2,0)=Q664950 [loddin]|(3,0)=Q890621 [bognor regis]|(4,0)=Q208262 [eastbourne]|(5,0)=Q1026748 [golden sands]|(6,0)=Q2467715 [sinemorets]|(7,0)=Q587765 [cleethorpes]|(8,0)=Q2921491 [katwijk aan zee]|(9,0)=Q2597695 [emona]',
#   'pool': "Q21042 [nebel];Q93612 [shropshire council];Q104882439 [proxmox backup server];Q2408401 [1965 french championships – women's singles];Q732548 [lagos];Q1341627 [rod mckuen];Q26779901 [skupina 5 dubů letních];Q27198702 [hararr dalata];Q61857049 [katwijk aan zee];Q1558158 [roubaix lille métropole];Q1026748 [golden sands];Q2467715 [sinemorets];Q27033228 [katwijk aan zee];Q21886079 [eastbourne];Q106216225 [gemeenteraad van jelsum];Q1278077 [eastbourne];Q315018 [nebel];Q61578982 [hallé];Q14334111 [template:gamespot];Q104083271 [furth, michael van];Q67622586 [[chm2007] hdc 1092];Q644350 [berlin-gesundbrunnen];Q1046077 [carvalhal];Q1131660 [stone];Q9397768 [jewish woman with lemons];Q208262 [eastbourne];Q2597695 [emona];Q1973218 [nebel];Q745016 [tour kuala lumpur];Q69480926 [springfield public library];Q261391 [william chambers];Q2921491 [katwijk aan zee];Q59523724 [igabi legislative council];Q490095 [lewis county];Q5329799 [eastbourne];Q10602944 [norrsunda];Q3294898 [iran castillo];Q890621 [bognor regis];Q42177274 [thor: ragnarok press kit];Q2464063 [colombia-coldeportes 2012];Q20743760 [encyclopedia of political theory (2010 ed.)];Q30584238 [ducey];Q1630 [hamburg-altona];Q20646763 [2015 fed cup europe/africa zone group i – play-offs];Q3542364 [turner];Q56851362 [douglas w. stephan];Q6923824 [mount stadler];Q26778224 [iglesia de santa maría la mayor];Q587765 [cleethorpes];Q77972398 [1994 thailand open badminton championships – men's doubles];Q110580334 [the .net core podcast];Q664950 [loddin];"},
#  {'dataset': 'wikidata_tables_2023',
#   'table': '6H4X23IR',
#   'instruction': 'perform the cell entity annotation (cea) task on this table:',
#   'input': 'Ielena;22103.118|Cntares.;|Antare;|Ramsgawe;|erry Azlea;20677.324|Gute;7646.464|Tarajo.;|Beachy Hebd.;23188.53|Estrden.;18132.18',
#   'output': '(1,0)=Q52336384 [helena]|(2,0)=Q18762841 [antares]|(3,0)=Q83645186 [antares]|(4,0)=Q106678142 [ramsgate]|(5,0)=Q21296915 [ferry azalea]|(6,0)=Q10573082 [gute]|(7,0)=Q106678129 [tarago]|(8,0)=Q11880108 [beachy head]|(9,0)=Q15622482 [estraden]',
#   'pool': "Q56405240 [hany m elsheikha];Q83645186 [antares];Q1046206 [ngc 1962];Q15339 [shlisselburg];Q1404659 [fenerbahçe women's volleyball];Q52336384 [helena];Q874954 [teodoro];Q106678142 [ramsgate];Q108123130 [wetherspoon];Q100717486 [vor der höhe];Q2766771 [prigorodny district, sverdlovsk oblast];Q751963 [pub];Q31853814 [dongguan];Q1473658 [washington, d.c.];Q37564766 [parian];Q10573082 [gute];Q67505731 [ward no. 5, chandrakona municipality];Q28006237 [st. joseph's commerce and banking historic district];Q5624689 [الگو:country data kurdistan region];Q21296915 [ferry azalea];Q7272307 [quinnipiac bobcats];Q953600 [estadio manuel martínez valero];Q27826669 [roubaix lille métropole 2017];Q29701375 [usine vacheron & constantin];Q63891738 [continental championship];Q47034620 [calasanz];Q19604414 [hammerstein schwebebahn station];Q111497746 [abraham and three angels];Q2310081 [perth];Q11880108 [beachy head];Q31345804 [rother berg];Q63464988 [ore ga suki nano wa imōto dakedo imōto ja nai];Q643412 [parliament of finland];Q18762841 [antares];Q13504419 [1993 spanish badminton championships];Q118727086 [a. viener];Q1753959 [dylan av bob dylan];Q106678129 [tarago];Q58263014 [1980 vuelta a aragón];Q15622482 [estraden];Q65922514 [1973 singapore open badminton championships – women's doubles];Q1636613 [pasila];Q21292983 [yale laundry];Q736462 [le lavandou];Q103968477 [stepwell];Q16223699 [justice];Q991209 [stevens point];Q7194327 [adventure time];"},
#  {'dataset': 'wikidata_tables_2023',
#   'table': 'PHLND4CO',
#   'instruction': 'perform the cell entity annotation (cea) task on this table:',
#   'input': 'Acheritou;Agios Georgios Acheritou|Achna;Dasaki Achnas',
#   'output': '(1,0)=Q56421343 [acheritou]|(1,1)=Q56759975 [agios georgios acheritou]|(2,0)=Q56421345 [achna]|(2,1)=Q25383246 [dasaki achnas]',
#   'pool': 'Q14265 [51 pegasi];Q39088122 [welsh government traffic officer];Q114246058 [llangattock];Q43085260 [gyumri restaurant, gyumri];Q2696309 [1965 french badminton championships];Q244510 [santarém];Q12075 [vilasar de dalt];Q2646776 [general-feldtseykhmeyster russian empire];Q115739185 [louvre];Q2540136 [1951 french championships];Q3330854 [north carolina maritime museum];Q56421343 [acheritou];Q56421345 [achna];Q56759975 [agios georgios acheritou];Q25383246 [dasaki achnas];Q8552663 [záblatí];'},
#  {'dataset': 'wikidata_tables_2023',
#   'table': 'D58GW2X4',
#   'instruction': 'perform the cell entity annotation (cea) task on this table:',
#   'input': 'Hurricane John;929|Hurricane Hugo;918|Hurricane Guillermo;919|Hurricane Linda;902|Hurricane Allen;899',
#   'output': '(1,0)=Q1638646 [hurricane john]|(2,0)=Q1638615 [hurricane hugo]|(3,0)=Q1477157 [hurricane guillermo]|(4,0)=Q1367109 [hurricane linda]|(5,0)=Q1346161 [hurricane allen]',
#   'pool': 'Q1367109 [hurricane linda];Q1477157 [hurricane guillermo];Q64358441 [hurricane john];Q10286562 [hurricane guillermo];Q39102967 [a diary of hurricane hugo];Q1638615 [hurricane hugo];Q10286566 [hurricane linda];Q21010089 [hurricane linda];Q3358406 [hurricane john];Q16180344 [hurricane];Q1346161 [hurricane allen];Q114141956 [the effects of hurricane allen];Q64516617 [hurricane guillermo];Q1638646 [hurricane john];'},
#  {'dataset': 'wikidata_tables_2023',
#   'table': 'JTL08N24',
#   'instruction': 'perform the cell entity annotation (cea) task on this table:',
#   'input': 'Firme del Barro;861|Loma Bajita;1671|Loma de Blanco;741|Loma del Convento;1392|Cerros Colorados;568|El Gajo de los Chivos;830|Loma del Diablo;217|Loma Damajagua;876|El Alto;699',
#   'output': '(1,0)=Q23779022 [firme del barro]|(2,0)=Q23778908 [loma bajita]|(3,0)=Q23778466 [loma de blanco]|(4,0)=Q23776757 [loma del convento]|(5,0)=Q23776715 [cerros colorados]|(6,0)=Q23776549 [el gajo de los chivos]|(7,0)=Q23776292 [loma del diablo]|(8,0)=Q23776243 [loma damajagua]|(9,0)=Q23775813 [el alto]',
#   'pool': "Q200124 [vayots dzor region];Q19155121 [dépêches du duc de wellington];Q1323273 [guido scala];Q23779022 [firme del barro];Q95434199 [jawaharlal nehru];Q23776715 [cerros colorados];Q23778908 [loma bajita];Q672735 [zal];Q3322490 [montcerf-lytton];Q1067380 [sega titan video];Q67146856 [1992 spanish team badminton championships];Q5989215 [template:redoutable class submarines];Q23776292 [loma del diablo];Q2673696 [przymorze];Q189018 [montenegro];Q14396327 [plantilla:mapa línia high speed 1];Q862740 [florence];Q23776757 [loma del convento];Q15697324 [immovable cultural heritage of public interest];Q30681053 [australia national blind cricket team];Q114257999 [1996 fa women's cup final];Q23778466 [loma de blanco];Q18155837 [mount toby formation];Q23776243 [loma damajagua];Q185029 [first-person shooter];Q61389000 [lääneranna veskiraha];Q36905238 [pully];Q28259557 [the smn complex];Q23776549 [el gajo de los chivos];Q29724851 [sncf];Q296381 [mikkeli];Q67165093 [mount rainier national park (naid 137930734)];Q23775813 [el alto];Q10537 [mühldorf am inn];Q12020677 [hrazený];Q57842951 [digital bedrock geologic map of the chester quadrangle, vermont];"},
#  {'dataset': 'wikidata_tables_2023',
#   'table': 'IN3NQZ9O',
#   'instruction': 'perform the cell entity annotation (cea) task on this table:',
#   'input': 'maternal grandparent;2|paternal grandparent;2|maternal great-grandparent;3|paternal great-grandparent;3|paternal grandfather;2|paternal grandmother;2|grandfather;2|grandmother;2',
#   'output': '(1,0)=Q28017614 [maternal grandparent]|(2,0)=Q28017613 [paternal grandparent]|(3,0)=Q26004701 [maternal great-grandparent]|(4,0)=Q19682171 [paternal great-grandparent]|(5,0)=Q19682162 [paternal grandfather]|(6,0)=Q12714606 [paternal grandmother]|(7,0)=Q9238344 [grandfather]|(8,0)=Q9235758 [grandmother]',
#   'pool': 'Q111399005 [paternal grandmother of tiberius];Q49751894 [willard airport];Q20317391 [template:user grandparent];Q2500619 [great-grandparent];Q19682171 [paternal great-grandparent];Q3258752 [grandmother];Q9238344 [grandfather];Q28017614 [maternal grandparent];Q68000026 [couvent des célestins];Q108614950 [paternal];Q9235758 [grandmother];Q28017613 [paternal grandparent];Q3571220 [grandmother];Q12433519 [paternal grandmother];Q1358919 [bicycle-sharing system];Q20318767 [template:user great-grandparent];Q60346808 [ahlbecker seegrund];Q26004701 [maternal great-grandparent];Q19682162 [paternal grandfather];Q167918 [grandparent];Q1987426 [all-euroleague basketball team];Q12714606 [paternal grandmother];Q109334876 [grandmother];Q664927 [doraemon];'},
#  {'dataset': 'wikidata_tables_2023',
#   'table': 'K0GLR5JP',
#   'instruction': 'perform the cell entity annotation (cea) task on this table:',
#   'input': 'Goulmima;16419|Ghafsai;6361|Oued Laou;9665|Foum Zguid;8986|Lahraouyine;64821|Fam El Hisn;6353|Er-Rich;25992|El Ouatia;9295',
#   'output': '(1,0)=Q3111649 [goulmima]|(2,0)=Q3104753 [ghafsai]|(3,0)=Q3099183 [oued laou]|(4,0)=Q3079930 [foum zguid]|(5,0)=Q3078218 [lahraouyine]|(6,0)=Q3064838 [fam el hisn]|(7,0)=Q3055931 [er-rich]|(8,0)=Q3050142 [el ouatia]',
#   'pool': 'Q3064838 [fam el hisn];Q1061925 [burwood];Q96708547 [indian journal of applied basic medical sciences];Q49362017 [porto covo];Q114456972 [helsinki olympic stadium tower];Q3055931 [er-rich];Q3079930 [foum zguid];Q14848076 [nicosia district south];Q66744635 [the vegetable stall];Q21654602 [okhotsk sea ice park];Q500939 [rock county];Q1134060 [susanna and the elders];Q1675241 [the ox];Q3050142 [el ouatia];Q86837540 [councillor in sandanski municipality];Q27031000 [1985 spanish international badminton championships];Q989270 [banbury];Q985231 [2011 sri lankan badminton championships];Q509745 [concordia];Q30509843 [glennon];Q3099183 [oued laou];Q111231487 [courtyard by marriott ottawa downtown];Q25242941 [saint joseph cathedral];Q14623618 [belisario domínguez municipality];Q3111649 [goulmima];Q12814852 [kaposvár];Q33440120 [hallas];Q3078218 [lahraouyine];Q13220650 [opéra comique];Q10940411 [honoakari];Q3104753 [ghafsai];Q22832602 [sjabloon:navigatie fed cup 2014];'},
#  {'dataset': 'wikidata_tables_2023',
#   'table': 'UEWS4EQU',
#   'instruction': 'perform the cell entity annotation (cea) task on this table:',
#   'input': 'Richmond Bridge;41|Old Bridge;200|Si-o-se Pol;297.76|Ponte dei Frati;6.64|Ponte Corvo;|Ponte San Martino;13.5|Puente Romano;792|Puente Romano;|Pont du Gard;900',
#   'output': '(1,0)=Q1079373 [richmond bridge]|(2,0)=Q435416 [old bridge]|(3,0)=Q667674 [si-o-se pol]|(4,0)=Q56877914 [ponte dei frati]|(5,0)=Q1428534 [ponte corvo]|(6,0)=Q57998710 [ponte san martino]|(7,0)=Q588535 [puente romano]|(8,0)=Q57598436 [puente romano]|(9,0)=Q189764 [pont du gard]',
#   'pool': "Q487356 [richmond bridge];Q163872 [the dark knight];Q1428534 [ponte corvo];Q64516414 [hurricane kenna];Q189764 [pont du gard];Q5399039 [esplanade sandstone];Q7700312 [tennis krishna];Q22355259 [mont rolland-germain];Q21508554 [bossert];Q116000575 [santa fè d'organyà];Q111368433 [clayton hotel birmingham];Q4971464 [british television science fiction];Q56877914 [ponte dei frati];Q10729125 [category b listed building];Q588535 [puente romano];Q611425 [champion system];Q953649 [almoster];Q1540732 [royal palace of la granja de san ildefonso];Q97625652 [puente romano];Q57598436 [puente romano];Q57998710 [ponte san martino];Q1079373 [richmond bridge];Q115025 [ontario county];Q10846908 [dream boy];Q52151467 [the pont du gard];Q435416 [old bridge];Q56528549 [pont du gard];Q5110203 [sexual diversity];Q667674 [si-o-se pol];Q215365 [brother bear];Q38146858 [richmond bridge];Q104064 [cologne];Q65102935 [2006 china open badminton championships – men's doubles];Q953508 [eastern province];Q4706429 [alan cox];"}]

# %%
def to_jsonl(llm_dataset_list: list, datasetName: str):
    with open(datasetName, 'w') as outfile:
        for entry in llm_dataset_list:
            json.dump(entry, outfile)
            outfile.write('\n')

# %%
to_jsonl(all_datasets, './output/pool/cea_pool.jsonl')

# %%
entity_set = set()
path = "./wikidata/WikidataTables2023R1/DataSets/Valid/gt/cta_gt.csv"
with open(os.path.join(path), 'r') as f:
    reader = csv.reader(f)
    for row in reader:
        entity_set.add(row[2])
len(entity_set)
# Out:
# 194
